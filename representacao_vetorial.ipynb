# %%
import json
import re

# Open and read file 
with open('corpus.json', 'r', encoding='utf-8') as file:
    content = file.read()

# Remove control characters using regex
cleaned_content = re.sub(r'[\x00-\x1F\x7F-\x9F]', '', content)

try:
    data = json.loads(cleaned_content)
    print("JSON loaded successfully!")

except json.JSONDecodeError as e:
    print(f"Having trouble loading JSON: {e}")

    error_location = e.pos
    start = max(0, error_location - 50)
    end = min(len(cleaned_content), error_location + 50)
    print(f"Context around the error: '{cleaned_content[start:end]}'")
# Out:
# JSON loaded successfully!

# %%
import json
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Supondo que 'data' já foi carregado anteriormente
tokenized_articles = [article.get('artigo_tokenizado', []) for article in data]
text_articles = [' '.join(tokens) for tokens in tokenized_articles]

# 1. Bag of Words (BoW)
bow_vectorizer = CountVectorizer()
bow_matrix = bow_vectorizer.fit_transform(text_articles)
vocabulary_bow = bow_vectorizer.get_feature_names_out()
word_to_index_bow = {word: i for i, word in enumerate(vocabulary_bow)}

# 2. TF-IDF
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(text_articles)
vocabulary_tfidf = tfidf_vectorizer.get_feature_names_out()
word_to_index_tfidf = {word: i for i, word in enumerate(vocabulary_tfidf)}

# 3. One-Hot
vocabulary_onehot = sorted({w for tokens in tokenized_articles for w in tokens})
word_to_index_onehot = {w: i for i, w in enumerate(vocabulary_onehot)}
identity_matrix = np.eye(len(vocabulary_onehot))

# Funções para obter top-N similares
def get_top_similar_tokens(matrix, vocabulary, word_to_index, token, top_n=10):
    if token not in word_to_index:
        return []
    
    # Para One-Hot Encoding, 'matrix' já é uma matriz densa, então não há necessidade de toarray()
    word_vectors = matrix.T  # Aqui transposta diretamente
    idx = word_to_index[token]
    vec = word_vectors[idx].reshape(1, -1)
    sims = cosine_similarity(vec, word_vectors)[0]
    
    # Ordena índices por similaridade desc, ignora o próprio token
    sorted_idx = np.argsort(sims)[::-1]
    similar = [vocabulary[i] for i in sorted_idx if i != idx]
    return similar[:top_n]


# Coleta top 10 similares para cada token em cada representação
top_similar_bow = {tok: get_top_similar_tokens(bow_matrix, vocabulary_bow, word_to_index_bow, tok) 
                   for tok in vocabulary_bow}
top_similar_tfidf = {tok: get_top_similar_tokens(tfidf_matrix, vocabulary_tfidf, word_to_index_tfidf, tok) 
                     for tok in vocabulary_tfidf}
# top_similar_onehot = {tok: get_top_similar_tokens(identity_matrix, vocabulary_onehot, word_to_index_onehot, tok) 
#                        for tok in vocabulary_onehot}


# A similaridade foi calculada para cada token em cada representação
overall_similarity = {
    'bow': top_similar_bow,
    'tfidf': top_similar_tfidf,
    # 'onehot': top_similar_onehot
}

overall_similarity
# Out:
# {'bow': {'aaai': ['groups',
#    'links',
#    'generator',
#    'vs',
#    'explicit',
#    'bleu',
#    'relied',
#    'steer',
#    'transformed',
#    'finetuned'],
#   'aae': ['kyriazi',
#    'leahy',
#    'hwu',
#    'lavaud',
#    'sudhakar',
#    'suffer',
#    'alpaca',
#    'evoking',
#    'vechtomova',
#    'neo'],
#   'aaron': ['suggestionignored',
#    'molina',
#    'owner',
#    'studio',
#    'stupid',
#    'pallets',
#    'aids',
#    'carrie',
#    'facepe',
#    'captures'],
#   'abacha': ['centered',
#    'handled',
#    'oncologists',
#    'lems',
#    'profiles',
#    'xxl',
#    'industries',
#    'cal',
#    'aforementioned',
#    'phenotypes'],
#   'abadi': ['softmax',
#    'stillwell',
#    'steinkraus',
#    'carl',
#    'marketing',
#    'algorithmic',
#    'carolina',
#    'square',
#    'martí',
#    'categorizing'],
#   'abadie': ['subtasks',
#    'martinet',
#    'hambro',
#    'computationally',
#    'pouget',
#    'farley',
#    'nash',
#    'fake',
#    'adjustable',
#    'mirza'],
#   'abbas': ['analytics',
#    'equipment',
#    'management',
#    'goals',
#    'powered',
#    'nation',
#    'promises',
#    'describing',
#    'allocation',
#    'refines'],
#   'abbasian': ['regimens',
#    'iot',
#    'stresses',
#    'estimating',
#    'goes',
#    'estimations',
#    'delay',
#    'ethape',
#    'deftness',
#    'kukreja'],
#   'abbeel': ['levine',
#    'me',
#    'tamp',
#    'action',
#    'icra',
#    'pastor',
#    'simultaneous',
#    'clark',
#    'fox',
#    'green'],
#   'abbreviation': ['dell',
#    'necessity',
#    'necessitated',
#    'necessarily',
#    'desire',
#    'vessel',
#    'vessels',
#    'vested',
#    'descendants',
#    'rainforest'],
#   'abcde': ['λnoobj',
#    'interconnected',
#    'inputted',
#    'vignat',
#    'vinicius',
#    'inception',
#    'ij',
#    'iet',
#    'hussain',
#    'homogeneous'],
#   'abdel': ['softmax',
#    'stillwell',
#    'steinkraus',
#    'carl',
#    'marketing',
#    'algorithmic',
#    'carolina',
#    'square',
#    'martí',
#    'categorizing'],
#   'abdelaziz': ['mismatched',
#    'cause',
#    'decent',
#    'paraphrase',
#    'paraphrases',
#    'aida',
#    'karanam',
#    'tjandra',
#    'meyer',
#    'kapanipathi'],
#   'abdi': ['disclosure',
#    'comprises',
#    'desktop',
#    'dados',
#    'op',
#    'cleaned',
#    'european',
#    'retraining',
#    'tabular',
#    'conclusions'],
#   'abdin': ['pentland',
#    'bendersky',
#    'doceng',
#    'dencia',
#    'conducts',
#    'man',
#    'reliably',
#    'behl',
#    'khaled',
#    'mand'],
#   'abdul': ['kyriazi',
#    'leahy',
#    'hwu',
#    'lavaud',
#    'sudhakar',
#    'suffer',
#    'alpaca',
#    'evoking',
#    'vechtomova',
#    'neo'],
#   'abdullah': ['bathroom',
#    'tial',
#    'valley',
#    'blukis',
#    'quested',
#    'finished',
#    'remembering',
#    'ready',
#    'griffiths',
#    'sofa'],
#   'abe': ['mismatched',
#    'cause',
#    'decent',
#    'paraphrase',
#    'paraphrases',
#    'aida',
#    'karanam',
#    'tjandra',
#    'meyer',
#    'kapanipathi'],
#   'abhimanyu': ['appreciable',
#    'flacke',
#    'nonspecific',
#    'sebastian',
#    'lcs',
#    'confirmed',
#    'normal',
#    'confuse',
#    'screened',
#    'unlocking'],
#   'abhishek': ['appreciable',
#    'flacke',
#    'nonspecific',
#    'sebastian',
#    'lcs',
#    'confirmed',
#    'normal',
#    'confuse',
#    'screened',
#    'unlocking'],
#   'abidin': ['softmax',
#    'stillwell',
#    'steinkraus',
#    'carl',
#    'marketing',
#    'algorithmic',
#    'carolina',
#    'square',
#    'martí',
#    'categorizing'],
#   'abilities': ['ning',
#    'duan',
#    'memory',
#    'reasoning',
#    'singh',
#    'term',
#    'manageable',
#    'realized',
#    'policies',
#    'luis'],
#   'ability': ['face',
#    'evaluating',
#    'widely',
#    'metric',
#    'similarity',
#    'hugging',
#    'cognitive',
#    'formatted',
#    'evaluate',
#    'design'],
#   'able': ['goals',
#    'management',
#    'powered',
#    'dynamic',
#    'virtual',
#    'application',
#    'abbas',
#    'analytics',
#    'powerful',
#    'contribute'],
#   'abnormalities': ['appreciable',
#    'flacke',
#    'nonspecific',
#    'sebastian',
#    'lcs',
#    'confirmed',
#    'normal',
#    'confuse',
#    'screened',
#    'unlocking'],
#   'about': ['system',
#    'resources',
#    'supported',
#    'iv',
#    'answer',
#    'following',
#    'expected',
#    'followed',
#    'consequently',
#    'at'],
#   'above': ['examinations',
#    'hospital',
#    'clin',
#    'segment',
#    'measurement',
#    'materials',
#    'millimeters',
#    'edges',
#    'costa',
#    'clinical'],
#   'abri': ['softmax',
#    'stillwell',
#    'steinkraus',
#    'carl',
#    'marketing',
#    'algorithmic',
#    'carolina',
#    'square',
#    'martí',
#    'categorizing'],
#   'abrupt': ['saqib',
#    'previews',
#    'gauvain',
#    'warm',
#    'unlabeled',
#    'concluded',
#    'tionally',
#    'rescue',
#    'translations',
#    'semester'],
#   'absence': ['holia',
#    'summarizes',
#    'pandya',
#    'none',
#    'quantitative',
#    'national',
#    'conversational',
#    'barrier',
#    'frustrated',
#    'plied'],
#   'absent': ['averaged',
#    'aleman',
#    'nvidia',
#    'struggling',
#    'differing',
#    'akkaya',
#    'excelled',
#    'struggled',
#    'achiam',
#    'check'],
#   'absolute': ['softmax',
#    'stillwell',
#    'steinkraus',
#    'carl',
#    'marketing',
#    'algorithmic',
#    'carolina',
#    'square',
#    'martí',
#    'categorizing'],
#   'abstr': ['kyriazi',
#    'leahy',
#    'hwu',
#    'lavaud',
#    'sudhakar',
#    'suffer',
#    'alpaca',
#    'evoking',
#    'vechtomova',
#    'neo'],
#   'abstract': ['at',
#    'apply',
#    'may',
#    'ieee',
#    'as',
#    'these',
#    'also',
#    'to',
#    'this',
#    'licensed'],
#   'abstracting': ['assisted',
#    'burden',
#    'initialize',
#    'visual',
#    'assessments',
#    'initialization',
#    'workflow',
#    'own',
#    'inspection',
#    'portugal'],
#   'abstraction': ['kyriazi',
#    'leahy',
#    'hwu',
#    'lavaud',
#    'sudhakar',
#    'suffer',
#    'alpaca',
#    'evoking',
#    'vechtomova',
#    'neo'],
#   'abstractions': ['bathroom',
#    'tial',
#    'valley',
#    'blukis',
#    'quested',
#    'finished',
#    'remembering',
#    'ready',
#    'griffiths',
#    'sofa'],
#   'abstracts': ['suggestionignored',
#    'molina',
#    'owner',
#    'studio',
#    'stupid',
#    'pallets',
#    'aids',
#    'carrie',
#    'facepe',
#    'captures'],
#   'abuse': ['pentland',
#    'bendersky',
#    'doceng',
#    'dencia',
#    'conducts',
#    'man',
#    'reliably',
#    'behl',
#    'khaled',
#    'mand'],
#   'acad': ['softmax',
#    'stillwell',
#    'steinkraus',
#    'carl',
#    'marketing',
#    'algorithmic',
#    'carolina',
#    'square',
#    'martí',
#    'categorizing'],
#   'academic': ['dell',
#    'necessity',
#    'necessitated',
#    'necessarily',
#    'desire',
#    'vessel',
#    'vessels',
#    'vested',
#    'descendants',
#    'rainforest'],
#   'academy': ['dave',
#    'mar',
#    'piracy',
#    'dec',
#    'icarus',
#    'rahayu',
#    'evol',
#    'baas',
#    'jaeger',
#    'rewrites'],
#   'acc': ['λnoobj',
#    'interconnected',
#    'inputted',
#    'vignat',
#    'vinicius',
#    'inception',
#    'ij',
#    'iet',
#    'hussain',
#    'homogeneous'],
#   'accelerate': ['dave',
#    'mar',
#    'piracy',
#    'dec',
#    'icarus',
#    'rahayu',
#    'evol',
#    'baas',
#    'jaeger',
#    'rewrites'],
#   'accelerated': ['converts',
#    'parada',
#    'grows',
#    'cortes',
#    'rettinghouse',
#    'bool',
#    'happen',
#    'clawed',
#    'sievers',
#    'flowchart'],
#   'accept': ['suggestionignored',
#    'molina',
#    'owner',
#    'studio',
#    'stupid',
#    'pallets',
#    'aids',
#    'carrie',
#    'facepe',
#    'captures'],
#   'acceptance': ['suggestionignored',
#    'molina',
#    'owner',
#    'studio',
#    'stupid',
#    'pallets',
#    'aids',
#    'carrie',
#    'facepe',
#    'captures'],
#   'accepted': ['copies',
#    'coding',
#    'extension',
#    'events',
#    'imposed',
#    'portions',
#    'porting',
#    'attempted',
#    'fications',
#    'polikarpova'],
#   'access': ['semantics',
#    'rely',
#    'prospects',
#    'alter',
#    'interventions',
#    'architecture',
#    'field',
#    'objectives',
#    'component',
#    'networks'],
#   'accessed': ['your',
#    'proposing',
#    'services',
#    'preliminary',
#    'private',
#    'view',
#    'refining',
#    'flows',
#    'configuring',
#    'application'],
#   'accessibility': ['chose',
#    'fuzzing',
#    'fse',
#    'nai',
#    'informational',
#    'nadi',
#    'informing',
#    'exhaustive',
#    'representational',
#    'executions'],
#   'accessible': ['morgan',
#    'focuses',
#    'grams',
#    'division',
#    'reflect',
#    'depicted',
#    'proportion',
#    'evaluations',
#    'interacting',
#    'mitigate'],
#   'accompanied': ['dell',
#    'necessity',
#    'necessitated',
#    'necessarily',
#    'desire',
#    'vessel',
#    'vessels',
#    'vested',
#    'descendants',
#    'rainforest'],
#   'accompanying': ['dell',
#    'necessity',
#    'necessitated',
#    'necessarily',
#    'desire',
#    'vessel',
#    'vessels',
#    'vested',
#    'descendants',
#    'rainforest'],
#   'accomplish': ['converts',
#    'parada',
#    'grows',
#    'cortes',
#    'rettinghouse',
#    'bool',
#    'happen',
#    'clawed',
#    'sievers',
#    'flowchart'],
#   'accordance': ['linked',
#    'papineni',
#    'teaching',
#    'scales',
#    'larochelle',
#    'incorporation',
#    'barcelona',
#    'schick',
#    'refer',
#    'spain'],
#   'according': ['provide',
#    'edge',
#    'included',
#    'again',
#    'could',
#    'despite',
#    'followed',
#    'they',
#    'way',
#    'concludes'],
#   'account': ['decoding',
#    'paraphrased',
#    'hours',
#    'speech',
#    'schalkwyk',
#    'rohit',
#    'density',
#    'lei',
#    'soria',
#    'sorin'],
#   'accounting': ['prehensive',
#    'encompasses',
#    'underexplored',
#    'raghavan',
#    'appear',
#    'cpu',
#    'tokenized',
#    'consistently',
#    'spaces',
#    'titles'],
#   'accounts': ['appreciable',
#    'flacke',
#    'nonspecific',
#    'sebastian',
#    'lcs',
#    'confirmed',
#    'normal',
#    'confuse',
#    'screened',
#    'unlocking'],
#   'accumulation': ['subtasks',
#    'martinet',
#    'hambro',
#    'computationally',
#    'pouget',
#    'farley',
#    'nash',
#    'fake',
#    'adjustable',
#    'mirza'],
#   'accuracies': ['wi',
#    'mathematical',
#    'nearest',
#    'forest',
#    'class',
#    'entropy',
#    'classify',
#    'neighbors',
#    'multi',
#    'tech'],
#   'accuracy': ['layer',
#    'machine',
#    'classification',
#    'forest',
#    'naive',
#    'neighbors',
#    'deep',
#    'problems',
#    'improve',
#    'which'],
#   'accurate': ['identifying',
#    'like',
#    'overall',
#    'study',
#    'consistently',
#    'light',
#    'manage',
#    'our',
#    'accounting',
#    'syntactic'],
#   'accurately': ['slight',
#    'fill',
#    'ground',
#    'extracting',
#    'effectiveness',
#    'unstructured',
#    'course',
#    'id',
#    'six',
#    'reporting'],
#   'achado': ['appreciable',
#    'flacke',
#    'nonspecific',
#    'sebastian',
#    'lcs',
#    'confirmed',
#    'normal',
#    'confuse',
#    'screened',
#    'unlocking'],
#   'acharya': ['pentland',
#    'bendersky',
#    'doceng',
#    'dencia',
#    'conducts',
#    'man',
#    'reliably',
#    'behl',
#    'khaled',
#    'mand'],
#   'achiam': ['adler',
#    'resulted',
#    'reality',
#    'absent',
#    'schmidt',
#    'aleman',
#    'akkaya',
#    'struggling',
#    'nvidia',
#    'judge'],
#   'achieve': ['can',
#    'problem',
#    'goal',
#    'propose',
#    'collaborative',
#    'simultaneously',
#    'wide',
#    'allows',
#    'bring',
#    'method'],
#   'achieved': ['additionally',
#    'include',
#    'and',
#    'higher',
#    'identified',
#    'for',
#    'several',
#    'review',
#    'enhance',
#    'integrating'],
#   'achievements': ['converts',
#    'parada',
#    'grows',
#    'cortes',
#    'rettinghouse',
#    'bool',
#    'happen',
#    'clawed',
#    'sievers',
#    'flowchart'],
#   'achieves': ['penalize',
#    'curse',
#    'landeghem',
#    'palo',
#    'carolina',
#    'superficially',
#    'kosinski',
#    'komisin',
#    'komiisin',
#    'arulkumaran'],
#   'achieving': ['art',
#    'comparison',
#    'demonstrating',
#    'study',
#    'developed',
#    'classifying',
#    'al',
#    'de',
#    'architectures',
#    'predicted'],
#   'acknowledge': ['revolutionizing',
#    'bots',
#    'golden',
#    'biology',
#    'electronic',
#    'similarities',
#    'closer',
#    'measured',
#    'count',
#    'bit'],
#   'acknowledgements': ['suggestionignored',
#    'molina',
#    'owner',
#    'studio',
#    'stupid',
#    'pallets',
#    'aids',
#    'carrie',
#    'facepe',
#    'captures'],
#   'acknowledgment': ['all',
#    'proach',
#    'becomes',
#    'advances',
#    'transactions',
#    'implementations',
#    'through',
#    'lu',
#    'unlike',
#    'ii'],
#   'acl': ['factual',
#    'categorized',
#    'experts',
#    'toxic',
#    'incorporation',
#    'refer',
#    'accordance',
#    'scales',
#    'encourage',
#    'schick'],
#   'acm': ['openai',
#    'server',
#    'software',
#    'run',
#    'how',
#    'sophisticated',
#    'interactions',
#    'collected',
#    'detailed',
#    'configured'],
#   'acoustic': ['mismatched',
#    'cause',
#    'decent',
#    'paraphrase',
#    'paraphrases',
#    'aida',
#    'karanam',
#    'tjandra',
#    'meyer',
#    'kapanipathi'],
#   'acoustics': ['frame',
#    'decoding',
#    'semantically',
#    'leftmost',
#    'lastras',
#    'portuguˆes',
#    'dinesh',
#    'povey',
#    'watanabe',
#    'ppl'],
#   'acquire': ['mismatched',
#    'cause',
#    'decent',
#    'paraphrase',
#    'paraphrases',
#    'aida',
#    'karanam',
#    'tjandra',
#    'meyer',
#    'kapanipathi'],
#   'acquired': ['center',
#    'intent',
#    'gb',
#    'core',
#    'ram',
#    'fan',
#    'ceived',
#    'emergence',
#    'translate',
#    'storing'],
#   'acquisition': ['glass',
#    'effectiveness',
#    'dexter',
#    'atheromatous',
#    'ate',
#    'assurance',
#    'prevention',
#    'hiroki',
#    'richard',
#    'hilar'],
#   'acr': ['appreciable',
#    'flacke',
#    'nonspecific',
#    'sebastian',
#    'lcs',
#    'confirmed',
#    'normal',
#    'confuse',
#    'screened',
#    'unlocking'],
#   'across': ['significantly',
#    'like',
#    'study',
#    'capture',
#    'media',
#    'big',
#    'nuances',
#    'overall',
#    'crucial',
#    'ensuring'],
#   'acso': ['saqib',
#    'previews',
#    'gauvain',
#    'warm',
#    'unlabeled',
#    'concluded',
#    'tionally',
#    'rescue',
#    'translations',
#    'semester'],
#   'act': ['mobility',
#    'agent',
#    'simulated',
#    'autonomously',
#    'ppi',
#    'interacts',
#    'perception',
#    'bridge',
#    'fulfill',
#    'mobile'],
#   'acted': ['indexing',
#    'gives',
#    'platforms',
#    'mondal',
#    'huge',
#    'subramanian',
#    'gated',
#    'consideration',
#    'recipe',
#    'recommendation'],
#   'acteristics': ['λnoobj',
#    'interconnected',
#    'inputted',
#    'vignat',
#    'vinicius',
#    'inception',
#    'ij',
#    'iet',
#    'hussain',
#    'homogeneous'],
#   'acting': ['ppi',
#    'perception',
#    'fulfill',
#    'interacts',
#    'bridge',
#    'simulation',
#    'environment',
#    'langchain',
#    'mobility',
#    'act'],
#   'action': ['tamp',
#    'me',
#    'levine',
#    'abbeel',
#    'simulations',
#    'robotic',
#    'red',
#    'room',
#    'requested',
#    'evolve'],
#   'actionable': ['manipulating',
#    'cohen',
#    'limiting',
#    'ichter',
#    'leaving',
#    'belong',
#    'ho',
#    'designated',
#    'transport',
#    'comments'],
#   'actions': ['agent',
#    'mobility',
#    'simulation',
#    'act',
#    'interacts',
#    'fulfill',
#    'ppi',
#    'perception',
#    'bridge',
#    'simulated'],
#   'activation': ['edited',
#    'sci',
#    'interests',
#    'professor',
#    'samples',
#    'generalization',
#    'attention',
#    'synthetic',
#    'along',
#    'london'],
#   'activations': ['kyriazi',
#    'leahy',
#    'hwu',
#    'lavaud',
#    'sudhakar',
#    'suffer',
#    'alpaca',
#    'evoking',
#    'vechtomova',
#    'neo'],
#   'active': ['inspection',
#    'arxiv',
#    'utilization',
#    'custom',
#    'conduct',
#    'studies',
#    'capability',
#    'other',
#    'public',
#    'integrated'],
#   'activities': ['adjusted',
#    'benefiting',
#    'cooking',
#    'fitting',
#    'responsibility',
#    'opinion',
#    'incorrect',
#    'bill',
#    'dialogue',
#    'reference'],
#   'activity': ['behaviors',
#    'seconds',
#    'app',
#    'track',
#    'tracking',
#    'young',
#    'get',
#    'cutting',
#    'mcduff',
#    'rising'],
#   'acts': ['dell',
#    'necessity',
#    'necessitated',
#    'necessarily',
#    'desire',
#    'vessel',
#    'vessels',
#    'vested',
#    'descendants',
#    'rainforest'],
#   'actual': ['automatic',
#    'general',
#    'since',
#    'de',
#    'consisting',
#    'formal',
#    'comparison',
#    'yu',
#    'labels',
#    'systems'],
#   'actually': ['kyriazi',
#    'leahy',
#    'hwu',
#    'lavaud',
#    'sudhakar',
#    'suffer',
#    'alpaca',
#    'evoking',
#    'vechtomova',
#    'neo'],
#   'ad': ['chose',
#    'fuzzing',
#    'fse',
#    'nai',
#    'informational',
#    'nadi',
#    'informing',
#    'exhaustive',
#    'representational',
#    'executions'],
#   'ada': ['singular',
#    'nulty',
#    'icaice',
#    'kadhim',
#    'mented',
#    'periment',
#    'lillis',
#    'quantifies',
#    'differently',
#    'quadratic'],
#   'adaboost': ['singular',
#    'nulty',
#    'icaice',
#    'kadhim',
#    'mented',
#    'periment',
#    'lillis',
#    'quantifies',
#    'differently',
#    'quadratic'],
#   'adam': ['vaes',
#    'matrix',
#    'kingma',
#    'ken',
#    'stabilize',
#    'bowden',
#    'exemplifies',
#    'ney',
#    'nicolau',
#    'everyday'],
#   'adamw': ['computers',
#    'embeddings',
#    'differently',
#    'asadpour',
#    'discriminant',
#    'ghz',
#    'asian',
#    'dipongkor',
#    'dings',
#    'subword'],
#   'adapt': ['querying',
#    'differs',
#    'directions',
#    'semantics',
#    'predefined',
#    'modifying',
#    'emnlp',
#    'controlled',
#    'prospects',
#    'interventions'],
#   'adaptability': ['gupta',
#    'formatting',
#    'indian',
#    'strict',
#    'recommender',
#    'compliance',
#    'returned',
#    'requirements',
#    'violation',
#    'grained'],
#   'adaptable': ['steven',
#    'cloning',
#    'notice',
#    'triggered',
#    'michael',
#    'andrew',
#    'examining',
#    'supports',
#    'transcribed',
#    'effort'],
#   'adaptation': ['eds',
#    'sentences',
#    'seed',
#    'qian',
#    'correction',
#    'autoregressive',
#    'frozen',
#    'preferable',
#    'choices',
#    'unrelated'],
#   'adapted': ['city',
#    'english',
#    'xie',
#    'resulting',
#    'typical',
#    'construct',
#    'fang',
#    'daniel',
#    'derived',
#    'modules'],
#   'adapter': ['populate',
#    'rio',
#    'graphic',
#    'translation',
#    'quantized',
#    'translating',
#    'mt',
#    'inclusion',
#    'rank',
#    'speaking'],
#   'adapters': ['financed',
#    'chasm',
#    'eichelbaum',
#    'confidentiality',
#    'streetmap',
#    'cci',
#    'geodata',
#    'else',
#    'stewart',
#    'preliminaries'],
#   'adapting': ['adjusting',
#    'han',
#    'scaling',
#    'text',
#    'empirical',
#    'ranking',
#    'dai',
#    'sentence',
#    'knowledge',
#    'increasing'],
#   'adaptive': ['managed',
#    'sensor',
#    'plant',
#    'fail',
#    'giving',
#    'counter',
#    'integrates',
#    'ensures',
#    'updated',
#    'singh'],
#   'adapts': ['kyriazi',
#    'leahy',
#    'hwu',
#    'lavaud',
#    'sudhakar',
#    'suffer',
#    'alpaca',
#    'evoking',
#    'vechtomova',
#    'neo'],
#   'add': ['joulin',
#    'reduction',
#    'tricks',
#    'mikolov',
#    'tail',
#    'grave',
#    'semantic',
#    'bojanowski',
#    'filtering',
#    'dnn'],
#   'added': ['llm',
#    'encoder',
#    'courville',
#    'goodfellow',
#    'balance',
#    'degrees',
#    'bengio',
#    'one',
#    'loss',
#    'several'],
#   'adder': ['dave',
#    'mar',
#    'piracy',
#    'dec',
#    'icarus',
#    'rahayu',
#    'evol',
#    'baas',
#    'jaeger',
#    'rewrites'],
#   'adding': ['contextually',
#    'techniques',
#    'volume',
#    'univ',
#    'prohibitive',
#    'emotional',
#    'gener',
#    'approving',
#    'coordinating',
#    'theories'],
#   'addition': ['penalty',
#    'belonging',
#    'simon',
#    'nor',
#    'welling',
#    'matrix',
#    'kingma',
#    'vaes',
#    'adam',
#    'gans'],
#   'additional': ['most',
#    'chain',
#    'negative',
#    'learn',
#    'survey',
#    'text',
#    'parameter',
#    'north',
#    'self',
#    'supervised'],
#   'additionally': ['them',
#    'achieved',
#    'process',
#    'demonstrated',
#    'tasks',
#    'as',
#    'while',
#    'but',
#    'and',
#    'for'],
#   'address': ['including',
#    'when',
#    'future',
#    'of',
#    'be',
#    'this',
#    'the',
#    'in',
#    'research',
#    'as'],
#   'addressed': ['email',
#    'vi',
#    'engines',
#    'draw',
#    'kong',
#    'foundational',
#    'considerations',
#    'complexity',
#    'engine',
#    'concerning'],
#   'addresses': ['benchmarking',
#    'analyses',
#    'role',
#    'validate',
#    'documentation',
#    'workflow',
#    'behavior',
#    'maximum',
#    'openai',
#    'less'],
#   'addressing': ['display',
#    'investigation',
#    'document',
#    'constructing',
#    'five',
#    'authors',
#    'exhibited',
#    'boyd',
#    'inaccurate',
#    'favor'],
#   'adds': ['synthetic',
#    'gong',
#    'generalization',
#    'existing',
#    'constructed',
#    'emotions',
#    'attempt',
#    'reduced',
#    'variance',
#    'poor'],
#   'adept': ['traffic',
#    'shami',
#    'vcpu',
#    'vcpus',
#    'reflection',
#    'reflexion',
#    'configures',
#    'verbal',
#    'regimen',
#    'orchestration'],
#   'adequately': ['pentland',
#    'bendersky',
#    'doceng',
#    'dencia',
#    'conducts',
#    'man',
#    'reliably',
#    'behl',
#    'khaled',
#    'mand'],
#   'aderemi': ['regimens',
#    'iot',
#    'stresses',
#    'estimating',
#    'goes',
#    'estimations',
#    'delay',
#    'ethape',
#    'deftness',
#    'kukreja'],
#   'adhere': ['contemporary',
#    'labor',
#    'behaviors',
#    'integrate',
#    'estimate',
#    'rules',
#    'must',
#    'item',
#    'drawbacks',
#    'totaling'],
#   'adhered': ['dell',
#    'necessity',
#    'necessitated',
#    'necessarily',
#    'desire',
#    'vessel',
#    'vessels',
#    'vested',
#    'descendants',
#    'rainforest'],
#   'adherence': ['suspected',
#    'reflects',
#    'adopting',
#    'population',
#    'undergoing',
#    'submitted',
#    'characterized',
#    'question',
#    'million',
#    'ed'],
#   'adheres': ['chose',
#    'fuzzing',
#    'fse',
#    'nai',
#    'informational',
#    'nadi',
#    'informing',
#    'exhaustive',
#    'representational',
#    'executions'],
#   'adhering': ['regulatory',
#    'returned',
#    'locations',
#    'violation',
#    'compliance',
#    'entities',
#    'entity',
#    'names',
#    'integral',
#    'uhrig'],
#   'adi': ['mismatched',
#    'cause',
#    'decent',
#    'paraphrase',
#    'paraphrases',
#    'aida',
#    'karanam',
#    'tjandra',
#    'meyer',
#    'kapanipathi'],
#   'adjust': ['multitask',
#    'subjective',
#    'controlled',
#    'adapt',
#    'modify',
#    'switch',
#    'lample',
#    'conversation',
#    'emnlp',
#    'transferring'],
#   'adjustable': ['subtasks',
#    'martinet',
#    'hambro',
#    'computationally',
#    'pouget',
#    'farley',
#    'nash',
#    'fake',
#    'mirza',
#    'azhar'],
#   'adjusted': ['cooking',
#    'benefiting',
#    'activities',
#    'fitting',
#    'responsibility',
#    'opinion',
#    'incorrect',
#    'bill',
#    'dialogue',
#    'units'],
#   'adjusting': ['sentence',
#    'optimal',
#    'adapting',
#    'linguistics',
#    'target',
#    'fold',
#    'transferring',
#    'neurons',
#    'graphs',
#    'policy'],
#   'adjustment': ['body',
#    'duarte',
#    'calculation',
#    'warning',
#    'trainable',
#    'coupled',
#    'jmlr',
#    'volumes',
#    'illustration',
#    'male'],
#   'adjustments': ['partial',
#    'asopa',
#    'repetitive',
#    'removes',
#    'distortions',
#    'ana',
#    'leave',
#    'hajishirzi',
#    'league',
#    'osorio'],
#   'adjusts': ['degree',
#    'choice',
#    'he',
#    'calculated',
#    'feed',
#    'tensorflow',
#    'optimization',
#    'balancing',
#    'transformer',
#    'objective'],
#   'adler': ['achiam',
#    'resulted',
#    'reality',
#    'absent',
#    'schmidt',
#    'aleman',
#    'akkaya',
#    'struggling',
#    'nvidia',
#    'judge'],
#   'administration': ['regimens',
#    'iot',
#    'stresses',
#    'estimating',
#    'goes',
#    'estimations',
#    'delay',
#    'ethape',
#    'deftness',
#    'kukreja'],
#   'administrators': ['traffic',
#    'shami',
#    'vcpu',
#    'vcpus',
#    'reflection',
#    'reflexion',
#    'configures',
#    'verbal',
#    'regimen',
#    'orchestration'],
#   'adopt': ['period',
#    'handling',
#    'advancing',
#    'finance',
#    'bird',
#    'places',
#    'date',
#    'advance',
#    'little',
#    'fair'],
#   'adopted': ['clin',
#    'mm',
#    'hospital',
#    'examinations',
#    'millimeters',
#    'materials',
#    'deaths',
#    'malignancy',
#    'segment',
#    'costa'],
#   'adopting': ['population',
#    'suspected',
#    'submitted',
#    'reflects',
#    'undergoing',
#    'characterized',
#    'million',
#    'frank',
#    'chinese',
#    'phenomenon'],
#   'adoption': ['component',
#    'components',
#    'define',
#    'drop',
#    'queried',
#    'ency',
#    'tao',
#    'zhen',
#    'opposed',
#    'prospects'],
#   'adopts': ['iteratively',
#    'lected',
#    'broad',
#    'stands',
#    'validation',
#    'ten',
#    'rigid',
#    'creation',
#    'capes',
#    'influence'],
#   'adriana': ['mismatched',
#    'cause',
#    'decent',
#    'paraphrase',
#    'paraphrases',
#    'aida',
#    'karanam',
#    'tjandra',
#    'meyer',
#    'kapanipathi'],
#   'adriell': ['λnoobj',
#    'interconnected',
#    'inputted',
#    'vignat',
#    'vinicius',
#    'inception',
#    'ij',
#    'iet',
#    'hussain',
#    'homogeneous'],
#   'adults': ['regimens',
#    'iot',
#    'stresses',
#    'estimating',
#    'goes',
#    'estimations',
#    'delay',
#    'ethape',
#    'deftness',
#    'kukreja'],
#   'adv': ['contrastive',
#    'student',
#    'syst',
#    'augmenting',
#    'comput',
#    'mach',
#    'amer',
#    'inf',
#    'strength',
#    'technol'],
#   'advance': ['shed',
#    'hovy',
#    'loper',
#    'bell',
#    'investigates',
#    'klein',
#    'nltk',
#    'complexities',
#    'classifications',
#    'toolkit'],
#   'advanced': ['key',
#    'capture',
#    'distinct',
#    'crucial',
#    'elements',
#    'significantly',
#    'across',
#    'york',
#    'ny',
#    'real'],
#   'advancement': ['co',
#    'narasimhan',
#    'lead',
#    'uncertainty',
#    'letter',
#    'jones',
#    'chosen',
#    'configuration',
#    'analysis',
#    'salimans'],
#   'advancements': ['enhances',
#    'direct',
#    'explored',
#    'methods',
#    'efficient',
#    'subsections',
#    'verified',
#    'vectors',
#    'shazeer',
#    'lee'],
#   'advances': ['unlike',
#    'finally',
#    'descriptions',
#    'conclusions',
#    'proposing',
#    'tabular',
#    'resources',
#    'presented',
#    'system',
#    'status'],
#   'advancing': ['period',
#    'adopt',
#    'complexities',
#    'ments',
#    'germany',
#    'locations',
#    'regulatory',
#    'legal',
#    'entities',
#    'pessoa'],
#   'advantage': ['bidirectional',
#    'manuscript',
#    'received',
#    'textual',
#    'machine',
#    'attention',
#    'along',
#    'papers',
#    'dimensionality',
#    'activation'],
#   'advantages': ['commonly',
#    'conclusions',
#    'retraining',
#    'mining',
#    'semantic',
#    'lifecycle',
#    'prioritization',
#    'maintenance',
#    'assigning',
#    'followed'],
#   'advent': ['song',
#    'wu',
#    'describe',
#    'shu',
#    'policies',
#    'laid',
#    'verifying',
#    'demands',
#    'fu',
#    'manageable'],
#   'adversarial': ['expensive',
#    'instruction',
#    'adv',
#    'relied',
#    'augmenting',
#    'comput',
#    'syst',
#    'contrastive',
#    'generator',
#    'student'],
#   'advice': ['regimens',
#    'iot',
#    'stresses',
#    'estimating',
#    'goes',
#    'estimations',
#    'delay',
#    'ethape',
#    'deftness',
#    'kukreja'],
#   'affect': ['conversely',
#    'financial',
#    'force',
#    'loper',
#    'advance',
#    'minor',
#    'deleting',
#    'protocol',
#    'uniform',
#    'replication'],
#   'affected': ['softmax',
#    'stillwell',
#    'steinkraus',
#    'carl',
#    'marketing',
#    'algorithmic',
#    'carolina',
#    'square',
#    'martí',
#    'categorizing'],
#   'affecting': ['predefined',
#    'displayed',
#    'dubey',
#    'querying',
#    'herd',
#    'adapt',
#    'influenced',
#    'varies',
#    'pessoa',
#    'roy'],
#   'affects': ['jargon',
#    'proprietary',
#    'formats',
#    'probably',
#    'names',
#    'chaplot',
#    'sablayrolles',
#    'casas',
#    'practitioners',
#    'bressand'],
#   'affinity': ['nicolau',
#    'moy',
#    'karras',
#    'mode',
#    'modelling',
#    'expressive',
#    'stone',
#    'stoll',
#    'glosses',
#    'glauert'],
#   'affirmation': ['financed',
#    'chasm',
#    'eichelbaum',
#    'confidentiality',
#    'streetmap',
#    'cci',
#    'geodata',
#    'else',
#    'stewart',
#    'preliminaries'],
#   'affordances': ['converts',
#    'parada',
#    'grows',
#    'cortes',
#    'rettinghouse',
#    'bool',
#    'happen',
#    'clawed',
#    'sievers',
#    'flowchart'],
#   'aforementioned': ['centered',
#    'handled',
#    'oncologists',
#    'lems',
#    'profiles',
#    'xxl',
#    'industries',
#    'cal',
#    'phenotypes',
#    'record'],
#   'aftandilian': ['suggestionignored',
#    'molina',
#    'owner',
#    'studio',
#    'stupid',
#    'pallets',
#    'aids',
#    'carrie',
#    'facepe',
#    'captures'],
#   'after': ['also',
#    'uses',
#    'these',
#    'using',
#    'at',
#    'ieee',
#    'and',
#    'abstract',
#    'as',
#    'that'],
#   'ag': ['softmax',
#    'stillwell',
#    'steinkraus',
#    'carl',
#    'marketing',
#    'algorithmic',
#    'carolina',
#    'square',
#    'martí',
#    'categorizing'],
#   'again': ['concludes',
#    'according',
#    'individual',
#    'maximizing',
#    'provide',
#    'included',
#    'edge',
#    'recommendations',
#    'benefit',
#    'increased'],
#   'against': ['overlap',
#    'overlaps',
#    'electronic',
#    'landscape',
#    'biology',
#    'sourced',
#    'specialized',
#    'bertscore',
#    'encompassing',
#    'websites'],
#   'agarwal': ['workshop',
#    'replace',
#    'xie',
#    'distillation',
#    'retain',
#    'excluding',
#    'verification',
#    'consists',
#    'zheng',
#    'deng'],
#   'age': ['mask',
#    'λnoobj',
#    'freitas',
#    'goh',
#    'geometry',
#    'geodesic',
#    'vries',
#    'gansau',
#    'scopic',
#    'fulham'],
#   'agement': ['singular',
#    'nulty',
#    'icaice',
#    'kadhim',
#    'mented',
#    'periment',
#    'lillis',
#    'quantifies',
#    'differently',
#    'quadratic'],
#   'agencies': ['chose',
#    'fuzzing',
#    'fse',
#    'nai',
#    'informational',
#    'nadi',
#    'informing',
#    'exhaustive',
#    'representational',
#    'executions'],
#   'agent': ['mobility',
#    'act',
#    'simulated',
#    'autonomous',
#    'agents',
#    'mobile',
#    'autonomously',
#    'actions',
#    'ppi',
#    'interacts'],
#   'agentic': ['traffic',
#    'shami',
#    'vcpu',
#    'vcpus',
#    'reflection',
#    'reflexion',
#    'configures',
#    'verbal',
#    'regimen',
#    'orchestration'],
#   'agents': ['routers',
#    'camps',
#    'depict',
#    'streaming',
#    'scraped',
#    'heighten',
#    'meneses',
#    'refines',
#    'verbal',
#    'depicts'],
#   'ages': ['nicolau',
#    'moy',
#    'karras',
#    'mode',
#    'modelling',
#    'expressive',
#    'stone',
#    'stoll',
#    'glosses',
#    'glauert'],
#   'aggregates': ['pentland',
#    'bendersky',
#    'doceng',
#    'dencia',
#    'conducts',
#    'man',
#    'reliably',
#    'behl',
#    'khaled',
#    'mand'],
#   'aggregating': ['kyriazi',
#    'leahy',
#    'hwu',
#    'lavaud',
#    'sudhakar',
#    'suffer',
#    'alpaca',
#    'evoking',
#    'vechtomova',
#    'neo'],
#   'aggregation': ['suggestionignored',
#    'molina',
#    'owner',
#    'studio',
#    'stupid',
#    'pallets',
#    'aids',
#    'carrie',
#    'facepe',
#    'captures'],
#   'agram': ['traffic',
#    'shami',
#    'vcpu',
#    'vcpus',
#    'reflection',
#    'reflexion',
#    'configures',
#    'verbal',
#    'regimen',
#    'orchestration'],
#   'agreement': ['centered',
#    'handled',
#    'oncologists',
#    'lems',
#    'profiles',
#    'xxl',
#    'industries',
#    'cal',
#    'aforementioned',
#    'phenotypes'],
#   'agriculture': ['dell',
#    'necessity',
#    'necessitated',
#    'necessarily',
#    'desire',
#    'vessel',
#    'vessels',
#    'vested',
#    'descendants',
#    'rainforest'],
#   'aguirre': ['saqib',
#    'previews',
#    'gauvain',
#    'warm',
#    'unlabeled',
#    'concluded',
#    'tionally',
#    'rescue',
#    'translations',
#    'semester'],
#   'agustini': ['dave',
#    'mar',
#    'piracy',
#    'dec',
#    'icarus',
#    'rahayu',
#    'evol',
#    'baas',
#    'jaeger',
#    'rewrites'],
#   'ahmad': ['empowering',
#    'efforts',
#    'evaluating',
#    'flexibility',
#    'register',
#    'design',
#    'unique',
#    'golden',
#    'practices',
#    'karri'],
#   'ahmed': ['receive',
#    'prototype',
#    'customization',
#    'rigorous',
#    'program',
#    'suggestions',
#    'bar',
#    'collect',
#    'researchers',
#    'app'],
#   'ahmedin': ['appreciable',
#    'flacke',
#    'nonspecific',
#    'sebastian',
#    'lcs',
#    'confirmed',
#    'normal',
#    'confuse',
#    'screened',
#    'unlocking'],
#   'ahn': ['proposed',
#    'manipulating',
#    'transport',
#    'coefficient',
#    'coordinates',
#    'located',
#    'confirm',
#    'inputting',
#    'remove',
#    'executed'],
#   'ai': ['artificial',
#    'robust',
#    'decisions',
#    'providing',
#    'intelligence',
#    'its',
#    'enhancing',
#    'applications',
#    'functions',
#    'abstract'],
#   'aid': ['measuring',
#    'incidence',
#    'clinical',
#    'decrease',
#    'heavy',
#    'edges',
#    'morphology',
#    'deviation',
#    'segment',
#    'biomedical'],
#   'aida': ['mismatched',
#    'cause',
#    'decent',
#    'paraphrase',
#    'paraphrases',
#    'karanam',
#    'tjandra',
#    'meyer',
#    'kapanipathi',
#    'macao'],
#   'aidan': ['illia',
#    'noam',
#    'shawn',
#    'llion',
#    'jesse',
#    'straightforward',
#    'ashish',
#    'lukasz',
#    'jakob',
#    'streamlining'],
#   'aided': ['pinto',
#    'refers',
#    'λnoobj',
#    'dermatology',
#    'vries',
#    'nosis',
#    'notched',
#    'dermoscopy',
#    'dermoscopic',
#    'dermatoscopy'],
#   'aiding': ['appreciable',
#    'flacke',
#    'nonspecific',
#    'sebastian',
#    'lcs',
#    'confirmed',
#    'normal',
#    'confuse',
#    'screened',
#    'unlocking'],
#   'aids': ['suggestionignored',
#    'molina',
#    'owner',
#    'studio',
#    'stupid',
#    'pallets',
#    'carrie',
#    'facepe',
#    'captures',
#    'replicates'],
#   'aila': ['nicolau',
#    'moy',
#    'karras',
#    'mode',
#    'modelling',
#    'expressive',
#    'stone',
#    'stoll',
#    'glosses',
#    'glauert'],
#   'aim': ['pre',
#    'step',
#    'close',
#    'performance',
#    'toward',
#    'distinguish',
#    'advent',
#    'ma',
#    'song',
#    'singh'],
#   'aimed': ['ease',
#    'appropriately',
#    'who',
#    'incorrect',
#    'answers',
#    'article',
#    'formulated',
#    'opinion',
#    'fitting',
#    'responsibility'],
#   'aiming': ['year',
#    'pipeline',
#    'stages',
#    'sion',
#    'ciˆencia',
#    'concatenation',
#    'sistemas',
#    'gradual',
#    'ultimately',
#    'knn'],
#   'aims': ['potentially',
#    'metrics',
#    'lower',
#    'strategy',
#    'significant',
#    'its',
#    'early',
#    'or',
#    'but',
#    'score'],
#   'air': ['softmax',
#    'stillwell',
#    'steinkraus',
#    'carl',
#    'marketing',
#    'algorithmic',
#    'carolina',
#    'square',
#    'martí',
#    'categorizing'],
#   'airbnb': ['softmax',
#    'stillwell',
#    'steinkraus',
#    'carl',
#    'marketing',
#    'algorithmic',
#    'carolina',
#    'square',
#    'martí',
#    'categorizing'],
#   'aist': ['chose',
#    'fuzzing',
#    'fse',
#    'nai',
#    'informational',
#    'nadi',
#    'informing',
#    'exhaustive',
#    'representational',
#    'executions'],
#   'ajanthan': ['nicolau',
#    'moy',
#    'karras',
#    'mode',
#    'modelling',
#    'expressive',
#    'stone',
#    'stoll',
#    'glosses',
#    'glauert'],
#   'aji': ['mismatched',
#    'cause',
#    'decent',
#    'paraphrase',
#    'paraphrases',
#    'aida',
#    'karanam',
#    'tjandra',
#    'meyer',
#    'kapanipathi'],
#   'akbar': ['softmax',
#    'stillwell',
#    'steinkraus',
#    'carl',
#    'marketing',
#    'algorithmic',
#    'carolina',
#    'square',
#    'martí',
#    'categorizing'],
#   'akbari': ['singular',
#    'nulty',
#    'icaice',
#    'kadhim',
#    'mented',
#    'periment',
#    'lillis',
#    'quantifies',
#    'differently',
#    'quadratic'],
#   'akhtar': ['kyriazi',
#    'leahy',
#    'hwu',
#    'lavaud',
#    'sudhakar',
#    'suffer',
#    'alpaca',
#    'evoking',
#    'vechtomova',
#    'neo'],
#   'akinci': ['regimens',
#    'iot',
#    'stresses',
#    'estimating',
#    'goes',
#    'estimations',
#    'delay',
#    'ethape',
#    'deftness',
#    'kukreja'],
#   'akkaya': ['averaged',
#    'aleman',
#    'nvidia',
#    'struggling',
#    'differing',
#    'absent',
#    'excelled',
#    'struggled',
#    'achiam',
#    'check'],
#   'akli': ['saqib',
#    'previews',
#    'gauvain',
#    'warm',
#    'unlabeled',
#    'concluded',
#    'tionally',
#    'rescue',
#    'translations',
#    'semester'],
#   'akmal': ['softmax',
#    'stillwell',
#    'steinkraus',
#    'carl',
#    'marketing',
#    'algorithmic',
#    'carolina',
#    'square',
#    'martí',
#    'categorizing'],
#   'akyürek': ['bathroom',
#    'tial',
#    'valley',
#    'blukis',
#    'quested',
#    'finished',
#    'remembering',
#    'ready',
#    'griffiths',
#    'sofa'],
#   'al': ['et',
#    'of',
#    'in',
#    'the',
#    'with',
#    'which',
#    'terms',
#    'this',
#    'such',
#    'future'],
#   'alacapinar': ['dave',
#    'mar',
#    'piracy',
#    'dec',
#    'icarus',
#    'rahayu',
#    'evol',
#    'baas',
#    'jaeger',
#    'rewrites'],
#   'alagoas': ['appreciable',
#    'flacke',
#    'nonspecific',
#    'sebastian',
#    'lcs',
#    'confirmed',
#    'normal',
#    'confuse',
#    'screened',
#    'unlocking'],
#   'alam': ['λnoobj',
#    'interconnected',
#    'inputted',
#    'vignat',
#    'vinicius',
#    'inception',
#    'ij',
#    'iet',
#    'hussain',
#    'homogeneous'],
#   'alamitos': ['chose',
#    'fuzzing',
#    'fse',
#    'nai',
#    'informational',
#    'nadi',
#    'informing',
#    'exhaustive',
#    'representational',
#    'executions'],
#   'alaniz': ['nicolau',
#    'moy',
#    'karras',
#    'mode',
#    'modelling',
#    'expressive',
#    'stone',
#    'stoll',
#    'glosses',
#    'glauert'],
#   'alarming': ['appreciable',
#    'flacke',
#    'nonspecific',
#    'sebastian',
#    'lcs',
#    'confirmed',
#    'normal',
#    'confuse',
#    'screened',
#    'unlocking'],
#   'alawadi': ['singular',
#    'nulty',
#    'icaice',
#    'kadhim',
#    'mented',
#    'periment',
#    'lillis',
#    'quantifies',
#    'differently',
#    'quadratic'],
#   'albeit': ['suggestionignored',
#    'molina',
#    'owner',
#    'studio',
#    'stupid',
#    'pallets',
#    'aids',
#    'carrie',
#    'facepe',
#    'captures'],
#   'albert': ['internet',
#    'vicuna',
#    'extensions',
#    'chiang',
#    'salimans',
#    'compatible',
#    'subsequently',
#    'facepe',
#    'anonymous',
#    'scholarship'],
#   'alberta': ['traffic',
#    'shami',
#    'vcpu',
#    'vcpus',
#    'reflection',
#    'reflexion',
#    'configures',
#    'verbal',
#    'regimen',
#    'orchestration'],
#   'alberto': ['saqib',
#    'previews',
#    'gauvain',
#    'warm',
#    'unlabeled',
#    'concluded',
#    'tionally',
#    'rescue',
#    'translations',
#    'semester'],
#   'albuquerque': ['λnoobj',
#    'interconnected',
#    'inputted',
#    'vignat',
#    'vinicius',
#    'inception',
#    'ij',
#    'iet',
#    'hussain',
#    'homogeneous'],
#   'aldoseri': ['centered',
#    'handled',
#    'oncologists',
#    'lems',
#    'profiles',
#    'xxl',
#    'industries',
#    'cal',
#    'aforementioned',
#    'phenotypes'],
#   'alec': ['suggestionignored',
#    'molina',
#    'owner',
#    'studio',
#    'stupid',
#    'pallets',
#    'aids',
#    'carrie',
#    'facepe',
#    'captures'],
#   'alejandra': ['suggestionignored',
#    'molina',
#    'owner',
#    'studio',
#    'stupid',
#    'pallets',
#    'aids',
#    'carrie',
#    'facepe',
#    'captures'],
#   'aleman': ['averaged',
#    'nvidia',
#    'struggling',
#    'differing',
#    'absent',
#    'akkaya',
#    'excelled',
#    'struggled',
#    'achiam',
#    'check'],
#   'alencar': ['traffic',
#    'shami',
#    'vcpu',
#    'vcpus',
#    'reflection',
#    'reflexion',
#    'configures',
#    'verbal',
#    'regimen',
#    'orchestration'],
#   'alenezi': ['singular',
#    'nulty',
#    'icaice',
#    'kadhim',
#    'mented',
#    'periment',
#    'lillis',
#    'quantifies',
#    'differently',
#    'quadratic'],
#   'alex': ['nan',
#    'hmm',
#    'johan',
#    'commonsense',
#    'hen',
#    'sachin',
#    'neelam',
#    'sadhana',
#    'saeki',
#    'jinyu'],
#   'alexei': ['mismatched',
#    'cause',
#    'decent',
#    'paraphrase',
#    'paraphrases',
#    'aida',
#    'karanam',
#    'tjandra',
#    'meyer',
#    'kapanipathi'],
#   'alexis': ['mismatched',
#    'cause',
#    'decent',
#    'paraphrase',
#    'paraphrases',
#    'aida',
#    'karanam',
#    'tjandra',
#    'meyer',
#    'kapanipathi'],
#   'alghowinem': ['dell',
#    'necessity',
#    'necessitated',
#    'necessarily',
#    'desire',
#    'vessel',
#    'vessels',
#    'vested',
#    'descendants',
#    'rainforest'],
#   'algorithm': ['solving',
#    'type',
#    'science',
#    'professor',
#    'attention',
#    'entropy',
#    'random',
#    'samples',
#    'edited',
#    'activation'],
#   'algorithmic': ['softmax',
#    'stillwell',
#    'steinkraus',
#    'carl',
#    'marketing',
#    'carolina',
#    'square',
#    'martí',
#    'categorizing',
#    'master'],
#   'algorithms': ['implemented',
#    'features',
#    'identifies',
#    'regression',
#    'world',
#    'outperformed',
#    'certain',
#    'traditional',
#    'continue',
#    'advanced'],
#   'alham': ['mismatched',
#    'cause',
#    'decent',
#    'paraphrase',
#    'paraphrases',
#    'aida',
#    'karanam',
#    'tjandra',
#    'meyer',
#    'kapanipathi'],
#   'ali': ['competitive',
#    'spaces',
#    'titles',
#    'auditing',
#    'title',
#    'raghavan',
#    'appear',
#    'whitehouse',
#    'recognizing',
#    'prehensive'],
#   'align': ['jointly',
#    'candidate',
#    'feasibility',
#    'position',
#    'mechanism',
#    'times',
#    'operations',
#    'let',
#    'understandable',
#    'ye'],
#   'aligned': ['prompted',
#    'wikipedia',
#    'steer',
#    'extent',
#    'shu',
#    'bleu',
#    'explicit',
#    'vs',
#    'links',
#    'guided'],
#   'aligning': ['compressing',
#    'jointly',
#    'partnership',
#    'candidate',
#    'product',
#    'align',
#    'rd',
#    'mohamed',
#    'stoyanov',
#    'luu'],
#   'alignmen': ['converts',
#    'parada',
#    'grows',
#    'cortes',
#    'rettinghouse',
#    'bool',
#    'happen',
#    'clawed',
#    'sievers',
#    'flowchart'],
#   'alignment': ['eds',
#    'connectionist',
#    'rewrite',
#    'autoregressive',
#    'correction',
#    'seed',
#    'am',
#    'dialog',
#    'paraphrasing',
#    'adaptation'],
#   'aligns': ['schuurmans',
#    'determining',
#    'bosma',
#    'palm',
#    'decreased',
#    'prefix',
#    'negative',
#    'systematic',
#    'blank',
#    'chenaghlu'],
#   'alina': ['dell',
#    'necessity',
#    'necessitated',
#    'necessarily',
#    'desire',
#    'vessel',
#    'vessels',
#    'vested',
#    'descendants',
#    'rainforest'],
#   'alkhayyat': ['regimens',
#    'iot',
#    'stresses',
#    'estimating',
#    'goes',
#    'estimations',
#    'delay',
#    'ethape',
#    'deftness',
#    'kukreja'],
#   'all': ['any',
#    'from',
#    'when',
#    'do',
#    'can',
#    'this',
#    'ness',
#    'address',
#    'value',
#    'indicate'],
#   'allen': ['nicolau',
#    'moy',
#    'karras',
#    'mode',
#    'modelling',
#    'expressive',
#    'stone',
#    'stoll',
#    'glosses',
#    'glauert'],
#   'allender': ['traffic',
#    'shami',
#    'vcpu',
#    'vcpus',
#    'reflection',
#    'reflexion',
#    'configures',
#    'verbal',
#    'regimen',
#    'orchestration'],
#   'alleviate': ['financed',
#    'chasm',
#    'eichelbaum',
#    'confidentiality',
#    'streetmap',
#    'cci',
#    'geodata',
#    'else',
#    'stewart',
#    'preliminaries'],
#   'alleviating': ['suggestionignored',
#    'molina',
#    'owner',
#    'studio',
#    'stupid',
#    'pallets',
#    'aids',
#    'carrie',
#    'facepe',
#    'captures'],
#   'allocation': ['sensors',
#    'tunning',
#    'abbas',
#    'analytics',
#    'management',
#    'equipment',
#    'goals',
#    'powered',
#    'shift',
#    'tified'],
#   'allow': ['users',
#    'shyam',
#    'neelakantan',
#    'subbiah',
#    'intentions',
#    'sastry',
#    'ryder',
#    'say',
#    'mann',
#    'inputs'],
#   'allowed': ['article',
#    'note',
#    'brazil',
#    'aimed',
#    'who',
#    'responsible',
#    'driven',
#    'related',
#    'incorrect',
#    'opinion'],
#   'allowing': ['effectively',
#    'university',
#    'field',
#    'your',
#    'conclusion',
#    'objectives',
#    'application',
#    'leverage',
#    'gathering',
#    'future'],
#   'allows': ['natural',
#    'into',
#    'involves',
#    'can',
#    'current',
#    'other',
#    'input',
#    'hand',
#    'achieve',
#    'them'],
#   'ally': ['nicolau',
#    'moy',
#    'karras',
#    'mode',
#    'modelling',
#    'expressive',
#    'stone',
#    'stoll',
#    'glosses',
#    'glauert'],
#   'almahairi': ['nicolau',
#    'moy',
#    'karras',
#    'mode',
#    'modelling',
#    'expressive',
#    'stone',
#    'stoll',
#    'glosses',
#    'glauert'],
#   'almazrouei': ['kyriazi',
#    'leahy',
#    'hwu',
#    'lavaud',
#    'sudhakar',
#    'suffer',
#    'alpaca',
#    'evoking',
#    'vechtomova',
#    'neo'],
#   'almeida': ['tag',
#    'preserved',
#    'computed',
#    'extracting',
#    'fill',
#    'professional',
#    'greatest',
#    'lateral',
#    'labeling',
#    'hu'],
#   'almost': ['job',
#    'dictionary',
#    'speed',
#    'every',
#    'generalized',
#    'working',
#    'microsoft',
#    'fang',
#    'versatile',
#    'common'],
#   'alone': ['bandwidth',
#    'paired',
#    'seems',
#    'resource',
#    'venkateswaran',
#    'quadruples',
#    'puneet',
#    'delta',
#    'puzzled',
#    'radhakrishnan'],
#   'along': ['attention',
#    'entropy',
#    'professor',
#    'samples',
#    'multi',
#    'imbalance',
#    'augmentation',
#    'machine',
#    'class',
#    'level'],
#   'alongside': ['oughly',
#    'providers',
#    'records',
#    'evaluations',
#    'showcasing',
#    'owing',
#    'mimic',
#    'cessed',
#    'protocols',
#    'implicitly'],
#   'aloud': ['suggestionignored',
#    'molina',
#    'owner',
#    'studio',
#    'stupid',
#    'pallets',
#    'aids',
#    'carrie',
#    'facepe',
#    'captures'],
#   'alowais': ['centered',
#    'handled',
#    'oncologists',
#    'lems',
#    'profiles',
#    'xxl',
#    'industries',
#    'cal',
#    'aforementioned',
#    'phenotypes'],
#   'alpaca': ['kyriazi',
#    'leahy',
#    'hwu',
#    'lavaud',
#    'sudhakar',
#    'suffer',
#    'evoking',
#    'vechtomova',
#    'neo',
#    'demanding'],
#   'alpha': ['financed',
#    'chasm',
#    'eichelbaum',
#    'confidentiality',
#    'streetmap',
#    'cci',
#    'geodata',
#    'else',
#    'stewart',
#    'preliminaries'],
#   'already': ['therefore',
#    'motion',
#    'group',
#    'placed',
#    'emphasizing',
#    'mentioned',
#    'employing',
#    'movement',
#    'energy',
#    'loop'],
#   'also': ['to', 'it', 'that', 'on', 'as', 'and', 'by', 'an', 'may', 'be'],
#   'altenschmidt': ['pentland',
#    'bendersky',
#    'doceng',
#    'dencia',
#    'conducts',
#    'man',
#    'reliably',
#    'behl',
#    'khaled',
#    'mand'],
#   'alter': ['interventions',
#    'prospects',
#    'semantics',
#    'component',
#    'differs',
#    'adapt',
#    'directions',
#    'access',
#    'drop',
#    'verified'],
#   'altered': ['kyriazi',
#    'leahy',
#    'hwu',
#    'lavaud',
#    'sudhakar',
#    'suffer',
#    'alpaca',
#    'evoking',
#    'vechtomova',
#    'neo'],
#   'altering': ['unexplored',
#    'content',
#    'prompting',
#    'transforming',
#    'gallipoli',
#    'differ',
#    'diao',
#    'beeching',
#    'pegf',
#    'pearson'],
#   'alternate': ['chose',
#    'fuzzing',
#    'fse',
#    'nai',
#    'informational',
#    'nadi',
#    'informing',
#    'exhaustive',
#    'representational',
#    'executions'],
#   'alternative': ['benchmark',
#    'fluency',
#    'yuan',
#    'skills',
#    'opposed',
#    'hill',
#    'tao',
#    'surprising',
#    'zhen',
#    'zhong'],
#   'alternatively': ['suggestionignored',
#    'molina',
#    'owner',
#    'studio',
#    'stupid',
#    'pallets',
#    'aids',
#    'carrie',
#    'facepe',
#    'captures'],
#   'alternatives': ['extreme',
#    'india',
#    'streamline',
#    'tracking',
#    'experience',
#    'estimation',
#    'outlining',
#    'educated',
#    'healthy',
#    'eating'],
#   'although': ['only',
#    'following',
#    'instructions',
#    'generated',
#    'possible',
#    'resources',
#    'followed',
#    'prompt',
#    'about',
#    'for'],
#   'altman': ['pentland',
#    'bendersky',
#    'doceng',
#    'dencia',
#    'conducts',
#    'man',
#    'reliably',
#    'behl',
#    'khaled',
#    'mand'],
#   'alto': ['softmax',
#    'stillwell',
#    'steinkraus',
#    'carl',
#    'marketing',
#    'algorithmic',
#    'carolina',
#    'square',
#    'martí',
#    'categorizing'],
#   'altogether': ['softmax',
#    'stillwell',
#    'steinkraus',
#    'carl',
#    'marketing',
#    'algorithmic',
#    'carolina',
#    'square',
#    'martí',
#    'categorizing'],
#   'aluru': ['λnoobj',
#    'interconnected',
#    'inputted',
#    'vignat',
#    'vinicius',
#    'inception',
#    'ij',
#    'iet',
#    'hussain',
#    'homogeneous'],
#   'alves': ['dell',
#    'necessity',
#    'necessitated',
#    'necessarily',
#    'desire',
#    'vessel',
#    'vessels',
#    'vested',
#    'descendants',
#    'rainforest'],
#   'always': ['chenaghlu',
#    'systematic',
#    'nikzad',
#    'blank',
#    'elicits',
#    'hope',
#    'amatriain',
#    'versus',
#    'dale',
#    'minaee'],
#   'am': ['autoregressive',
#    'correction',
#    'connectionist',
#    'rewrite',
#    'seed',
#    'paraphrasing',
#    'dialog',
#    'eds',
#    'frozen',
#    'roukos'],
#   'amatriain': ['chenaghlu',
#    'systematic',
#    'always',
#    'nikzad',
#    'blank',
#    'elicits',
#    'hope',
#    'versus',
#    'dale',
#    'minaee'],
#   'amazon': ['competes',
#    'hunting',
#    'hundreds',
#    'humanidades',
#    'compilation',
#    'rainforest',
#    'hooks',
#    'honor',
#    'competent',
#    'race'],
#   'amazˆonia': ['publishers',
#    'posing',
#    'felipe',
#    'aside',
#    'skill',
#    'aspect',
#    'civil',
#    'division',
#    'suggests',
#    'contextualized'],
#   'ambiguities': ['pentland',
#    'bendersky',
#    'doceng',
#    'dencia',
#    'conducts',
#    'man',
#    'reliably',
#    'behl',
#    'khaled',
#    'mand'],
#   'ambiguous': ['singular',
#    'nulty',
#    'icaice',
#    'kadhim',
#    'mented',
#    'periment',
#    'lillis',
#    'quantifies',
#    'differently',
#    'quadratic'],
#   'amer': ['contrastive',
#    'student',
#    'zeng',
#    'mentation',
#    'adv',
#    'syst',
#    'technol',
#    'augmenting',
#    'comput',
#    'she'],
#   'american': ['left',
#    'middle',
#    'ct',
#    'extract',
#    'unstructured',
#    'lateral',
#    'greatest',
#    'scheme',
#    'meticulous',
#    'meysam'],
#   'amershi': ['kyriazi',
#    'leahy',
#    'hwu',
#    'lavaud',
#    'sudhakar',
#    'suffer',
#    'alpaca',
#    'evoking',
#    'vechtomova',
#    'neo'],
#   'amf': ['traffic',
#    'shami',
#    'vcpu',
#    'vcpus',
#    'reflection',
#    'reflexion',
#    'configures',
#    'verbal',
#    'regimen',
#    'orchestration'],
#   'amir': ['appreciable',
#    'flacke',
#    'nonspecific',
#    'sebastian',
#    'lcs',
#    'confirmed',
#    'normal',
#    'confuse',
#    'screened',
#    'unlocking'],
# ...
#    'speeding',
#    'spread',
#    'congregate',
#    'leaning',
#    'stakes',
#    'diagnose',
#    'record',
#    'genetic',
#    'industries'],
#   'boost': ['yielded',
#    'began',
#    'resour',
#    'nonetheless',
#    'gains',
#    'replaced',
#    'harmonic',
#    'builds',
#    'member',
#    'gaps'],
#   'boosting': ['reviewed',
#    'resolving',
#    'logistic',
#    'exists',
#    'pooling',
#    'richer',
#    'heads',
#    'francisco',
#    'prati',
#    'unbiased'],
#   'bordas': ['months',
#    'denny',
#    'alarming',
#    'degenerative',
#    'sively',
#    'alagoas',
#    'linda',
#    'multislice',
#    'delimit',
#    'multiplanar'],
#   'borderline': ['softmax',
#    'gopali',
#    'carl',
#    'marketing',
#    'carolina',
#    'square',
#    'martí',
#    'categorizing',
#    'master',
#    'specializes'],
#   'borders': ['λnoobj',
#    'waiting',
#    'kalebasi',
#    'jerovane',
#    'jama',
#    'jaccard',
#    'jac',
#    'jaborandy',
#    'isriti',
#    'isic'],
#   'bors': ['naseem',
#    'demeyer',
#    'akbari',
#    'historical',
#    'denote',
#    'website',
#    'nobody',
#    'dependent',
#    'meanwhile',
#    'baeza'],
#   'bosch': ['softmax',
#    'gopali',
#    'carl',
#    'marketing',
#    'carolina',
#    'square',
#    'martí',
#    'categorizing',
#    'master',
#    'specializes'],
#   'bosma': ['determining',
#    'schuurmans',
#    'aligns',
#    'palm',
#    'dale',
#    'foster',
#    'minaee',
#    'nikzad',
#    'elicits',
#    'blank'],
#   'bosselut': ['skgprompt',
#    'gst',
#    'barzilay',
#    'komeili',
#    'alpaca',
#    'vechtomova',
#    'kojima',
#    'gru',
#    'knowledgpt',
#    'velutharambath'],
#   'bot': ['dell',
#    'qualified',
#    'punishments',
#    'universities',
#    'purchase',
#    'purse',
#    'united',
#    'putational',
#    'devoted',
#    'quartey'],
#   'both': ['their',
#    'or',
#    'another',
#    'with',
#    'information',
#    'significant',
#    'struggle',
#    'often',
#    'et',
#    'only'],
#   'bots': ['revolutionizing',
#    'acknowledge',
#    'golden',
#    'biology',
#    'electronic',
#    'similarities',
#    'valuable',
#    'closer',
#    'against',
#    'measured'],
#   'botsis': ['months',
#    'denny',
#    'alarming',
#    'degenerative',
#    'sively',
#    'alagoas',
#    'linda',
#    'multislice',
#    'delimit',
#    'multiplanar'],
#   'bottleneck': ['mismatched',
#    'assumption',
#    'ron',
#    'mesmo',
#    'alham',
#    'merve',
#    'triples',
#    'convolution',
#    'rohit',
#    'alexis'],
#   'bottom': ['mismatched',
#    'assumption',
#    'ron',
#    'mesmo',
#    'alham',
#    'merve',
#    'triples',
#    'convolution',
#    'rohit',
#    'alexis'],
#   'bouamor': ['mismatched',
#    'assumption',
#    'ron',
#    'mesmo',
#    'alham',
#    'merve',
#    'triples',
#    'convolution',
#    'rohit',
#    'alexis'],
#   'bougares': ['signers',
#    'speakers',
#    'alaniz',
#    'warping',
#    'gaussian',
#    'garlic',
#    'koller',
#    'chu',
#    'translates',
#    'ganguli'],
#   'boukhayma': ['signers',
#    'speakers',
#    'alaniz',
#    'warping',
#    'gaussian',
#    'garlic',
#    'koller',
#    'chu',
#    'translates',
#    'ganguli'],
#   'bound': ['signers',
#    'speakers',
#    'alaniz',
#    'warping',
#    'gaussian',
#    'garlic',
#    'koller',
#    'chu',
#    'translates',
#    'ganguli'],
#   'boundaries': ['pentland',
#    'diverges',
#    'temath',
#    'koubarakis',
#    'bigdata',
#    'bilenko',
#    'inlegalner',
#    'heng',
#    'empirist',
#    'wac'],
#   'boundary': ['excellent',
#    'symbols',
#    'why',
#    'block',
#    'jung',
#    'william',
#    'mohammad',
#    'character',
#    'consisted',
#    'rescoring'],
#   'bounding': ['λnoobj',
#    'waiting',
#    'kalebasi',
#    'jerovane',
#    'jama',
#    'jaccard',
#    'jac',
#    'jaborandy',
#    'isriti',
#    'isic'],
#   'boureau': ['skgprompt',
#    'gst',
#    'barzilay',
#    'komeili',
#    'alpaca',
#    'vechtomova',
#    'kojima',
#    'gru',
#    'knowledgpt',
#    'velutharambath'],
#   'bousquet': ['skgprompt',
#    'gst',
#    'barzilay',
#    'komeili',
#    'alpaca',
#    'vechtomova',
#    'kojima',
#    'gru',
#    'knowledgpt',
#    'velutharambath'],
#   'bow': ['cambridge',
#    'assigned',
#    'tf',
#    'idf',
#    'categorical',
#    'dense',
#    'unbiased',
#    'pooling',
#    'prati',
#    'heads'],
#   'bowden': ['signers',
#    'speakers',
#    'alaniz',
#    'warping',
#    'gaussian',
#    'garlic',
#    'koller',
#    'chu',
#    'translates',
#    'ganguli'],
#   'bowen': ['mismatched',
#    'assumption',
#    'ron',
#    'mesmo',
#    'alham',
#    'merve',
#    'triples',
#    'convolution',
#    'rohit',
#    'alexis'],
#   'bowl': ['lozano',
#    'grasped',
#    'falling',
#    'roberto',
#    'grasps',
#    'rep',
#    'communicates',
#    'tv',
#    'velocity',
#    'vemprala'],
#   'bowyer': ['softmax',
#    'gopali',
#    'carl',
#    'marketing',
#    'carolina',
#    'square',
#    'martí',
#    'categorizing',
#    'master',
#    'specializes'],
#   'box': ['cover',
#    'versions',
#    'analyses',
#    'combinations',
#    'carlos',
#    'montolli',
#    'nai',
#    'rajagopal',
#    'nadi',
#    'mon'],
#   'boxes': ['panda',
#    'fusion',
#    'confirming',
#    'segments',
#    'cnn',
#    'yi',
#    'combination',
#    'probability',
#    'automatic',
#    'detection'],
#   'boyd': ['exhibited',
#    'comment',
#    'efficacy',
#    'inaccurate',
#    'little',
#    'mental',
#    'equally',
#    'favor',
#    'fair',
#    'exhibiting'],
#   'bpfs': ['softmax',
#    'gopali',
#    'carl',
#    'marketing',
#    'carolina',
#    'square',
#    'martí',
#    'categorizing',
#    'master',
#    'specializes'],
#   'br': ['pentland',
#    'diverges',
#    'temath',
#    'koubarakis',
#    'bigdata',
#    'bilenko',
#    'inlegalner',
#    'heng',
#    'empirist',
#    'wac'],
#   'brady': ['months',
#    'denny',
#    'alarming',
#    'degenerative',
#    'sively',
#    'alagoas',
#    'linda',
#    'multislice',
#    'delimit',
#    'multiplanar'],
#   'brain': ['λnoobj',
#    'waiting',
#    'kalebasi',
#    'jerovane',
#    'jama',
#    'jaccard',
#    'jac',
#    'jaborandy',
#    'isriti',
#    'isic'],
#   'branch': ['naseem',
#    'demeyer',
#    'akbari',
#    'historical',
#    'denote',
#    'website',
#    'nobody',
#    'dependent',
#    'meanwhile',
#    'baeza'],
#   'branches': ['kishore',
#    'draw',
#    'kong',
#    'engines',
#    'preserve',
#    'foundational',
#    'considerations',
#    'vii',
#    'list',
#    'package'],
#   'brand': ['softmax',
#    'gopali',
#    'carl',
#    'marketing',
#    'carolina',
#    'square',
#    'martí',
#    'categorizing',
#    'master',
#    'specializes'],
#   'branding': ['softmax',
#    'gopali',
#    'carl',
#    'marketing',
#    'carolina',
#    'square',
#    'martí',
#    'categorizing',
#    'master',
#    'specializes'],
#   'branson': ['mismatched',
#    'assumption',
#    'ron',
#    'mesmo',
#    'alham',
#    'merve',
#    'triples',
#    'convolution',
#    'rohit',
#    'alexis'],
#   'brasil': ['curation',
#    'mentioning',
#    'family',
#    'amazon',
#    'billion',
#    'email',
#    'draw',
#    'kong',
#    'engines',
#    'national'],
#   'brasileiro': ['termined',
#    'overpassql',
#    'paragraph',
#    'tically',
#    'parsers',
#    'exploitation',
#    'behaviour',
#    'exciting',
#    'pessoal',
#    'petrobras'],
#   'bray': ['λnoobj',
#    'waiting',
#    'kalebasi',
#    'jerovane',
#    'jama',
#    'jaccard',
#    'jac',
#    'jaborandy',
#    'isriti',
#    'isic'],
#   'brazil': ['refined',
#    'themselves',
#    'facilitate',
#    'responsible',
#    'ploying',
#    'ized',
#    'provision',
#    'outdated',
#    'displaying',
#    'centro'],
#   'brazilian': ['law',
#    'laws',
#    'day',
#    'nets',
#    'documents',
#    'exclusive',
#    'hypothesis',
#    'inappropriate',
#    'judging',
#    'outlined'],
#   'breaban': ['softmax',
#    'gopali',
#    'carl',
#    'marketing',
#    'carolina',
#    'square',
#    'martí',
#    'categorizing',
#    'master',
#    'specializes'],
#   'breaking': ['operates',
#    'iterative',
#    'verifies',
#    'put',
#    'shah',
#    'scalable',
#    'pereira',
#    'failure',
#    'logical',
#    'robustness'],
#   'breaks': ['lozano',
#    'grasped',
#    'falling',
#    'roberto',
#    'grasps',
#    'rep',
#    'communicates',
#    'tv',
#    'velocity',
#    'vemprala'],
#   'breast': ['centered',
#    'speeding',
#    'spread',
#    'congregate',
#    'leaning',
#    'stakes',
#    'diagnose',
#    'record',
#    'genetic',
#    'industries'],
#   'breazeal': ['respect',
#    'federated',
#    'attainable',
#    'item',
#    'enter',
#    'associations',
#    'department',
#    'behaviors',
#    'emphasizing',
#    'chatbots'],
#   'brendan': ['insecure',
#    'pernambuco',
#    'multitude',
#    'win',
#    'ging',
#    'git',
#    'permission',
#    'seamlessly',
#    'perry',
#    'rifkin'],
#   'bressand': ['sablayrolles',
#    'chaplot',
#    'mensch',
#    'casas',
#    'practitioners',
#    'affects',
#    'jargon',
#    'gu',
#    'pan',
#    'formats'],
#   'brett': ['months',
#    'denny',
#    'alarming',
#    'degenerative',
#    'sively',
#    'alagoas',
#    'linda',
#    'multislice',
#    'delimit',
#    'multiplanar'],
#   'brian': ['months',
#    'denny',
#    'alarming',
#    'degenerative',
#    'sively',
#    'alagoas',
#    'linda',
#    'multislice',
#    'delimit',
#    'multiplanar'],
#   'bridge': ['ppi',
#    'fulfill',
#    'perception',
#    'interacts',
#    'acting',
#    'simulation',
#    'actions',
#    'mobility',
#    'act',
#    'environment'],
#   'bridges': ['pentland',
#    'diverges',
#    'temath',
#    'koubarakis',
#    'bigdata',
#    'bilenko',
#    'inlegalner',
#    'heng',
#    'empirist',
#    'wac'],
#   'bridging': ['translate',
#    'storing',
#    'emergence',
#    'expert',
#    'ref',
#    'semantics',
#    'controlled',
#    'massive',
#    'enough',
#    'proposing'],
#   'brief': ['concluding',
#    'direct',
#    'worse',
#    'le',
#    'guo',
#    'chapter',
#    'gies',
#    'larger',
#    'mitchell',
#    'tao'],
#   'briefings': ['tian',
#    'histogram',
#    'trends',
#    'dangerous',
#    'asked',
#    'topic',
#    'evaluated',
#    'rouge',
#    'qa',
#    'insight'],
#   'briefly': ['proves',
#    'implements',
#    'status',
#    'simpler',
#    'return',
#    'turbo',
#    'descriptions',
#    'package',
#    'tables',
#    'keyword'],
#   'briggs': ['softmax',
#    'gopali',
#    'carl',
#    'marketing',
#    'carolina',
#    'square',
#    'martí',
#    'categorizing',
#    'master',
#    'specializes'],
#   'brightness': ['softmax',
#    'gopali',
#    'carl',
#    'marketing',
#    'carolina',
#    'square',
#    'martí',
#    'categorizing',
#    'master',
#    'specializes'],
#   'bring': ['destination',
#    'observation',
#    'collaborative',
#    'inside',
#    'true',
#    'mordatch',
#    'fikes',
#    'mccandlish',
#    'theorem',
#    'avoidance'],
#   'bringing': ['lozano',
#    'grasped',
#    'falling',
#    'roberto',
#    'grasps',
#    'rep',
#    'communicates',
#    'tv',
#    'velocity',
#    'vemprala'],
#   'brings': ['naseem',
#    'demeyer',
#    'akbari',
#    'historical',
#    'denote',
#    'website',
#    'nobody',
#    'dependent',
#    'meanwhile',
#    'baeza'],
#   'broad': ['stands',
#    'rigid',
#    'ten',
#    'iteratively',
#    'lected',
#    'adopts',
#    'creation',
#    'influence',
#    'receives',
#    'constraints'],
#   'broadening': ['insecure',
#    'pernambuco',
#    'multitude',
#    'win',
#    'ging',
#    'git',
#    'permission',
#    'seamlessly',
#    'perry',
#    'rifkin'],
#   'broader': ['devised',
#    'interpreting',
#    'ings',
#    'ji',
#    'costly',
#    'paradigm',
#    'hallucination',
#    'dynamically',
#    'decisions',
#    'reducing'],
#   'broadly': ['fit',
#    'marco',
#    'perparameters',
#    'maintained',
#    'salvador',
#    'perceptions',
#    'spective',
#    'howard',
#    'saqib',
#    'bahia'],
#   'brohan': ['converts',
#    'unfamiliar',
#    'unintentional',
#    'arranging',
#    'arrangement',
#    'arranged',
#    'arrange',
#    'hesse',
#    'memorize',
#    'pathak'],
#   'bronchi': ['months',
#    'denny',
#    'alarming',
#    'degenerative',
#    'sively',
#    'alagoas',
#    'linda',
#    'multislice',
#    'delimit',
#    'multiplanar'],
#   'broncho': ['months',
#    'denny',
#    'alarming',
#    'degenerative',
#    'sively',
#    'alagoas',
#    'linda',
#    'multislice',
#    'delimit',
#    'multiplanar'],
#   'brosof': ['regimens',
#    'gavaravarapu',
#    'dependable',
#    'korrapati',
#    'gandhinagar',
#    'advice',
#    'iraq',
#    'gamification',
#    'estimating',
#    'iot'],
#   'brought': ['overload',
#    'investigations',
#    'rendering',
#    'supposed',
#    'interpretative',
#    'outcome',
#    'navigation',
#    'red',
#    'mentioned',
#    'place'],
#   'brown': ['amodei',
#    'child',
#    'learners',
#    'radford',
#    'sutskever',
#    'owned',
#    'prerequisites',
#    'feasibility',
#    'consider',
#    'jiang'],
#   'bs': ['termined',
#    'overpassql',
#    'paragraph',
#    'tically',
#    'parsers',
#    'exploitation',
#    'behaviour',
#    'exciting',
#    'pessoal',
#    'petrobras'],
#   'bubble': ['skgprompt',
#    'gst',
#    'barzilay',
#    'komeili',
#    'alpaca',
#    'vechtomova',
#    'kojima',
#    'gru',
#    'knowledgpt',
#    'velutharambath'],
#   'bucker': ['lozano',
#    'grasped',
#    'falling',
#    'roberto',
#    'grasps',
#    'rep',
#    'communicates',
#    'tv',
#    'velocity',
#    'vemprala'],
#   'budget': ['version',
#    'coverage',
#    'compiling',
#    'nlbse',
#    'endpoint',
#    'flagged',
#    'agencies',
#    'endpoints',
#    'fixture',
#    'enforcement'],
#   'budgetary': ['dell',
#    'qualified',
#    'punishments',
#    'universities',
#    'purchase',
#    'purse',
#    'united',
#    'putational',
#    'devoted',
#    'quartey'],
#   'budhiman': ['λnoobj',
#    'waiting',
#    'kalebasi',
#    'jerovane',
#    'jama',
#    'jaccard',
#    'jac',
#    'jaborandy',
#    'isriti',
#    'isic'],
#   'buehler': ['naseem',
#    'demeyer',
#    'akbari',
#    'historical',
#    'denote',
#    'website',
#    'nobody',
#    'dependent',
#    'meanwhile',
#    'baeza'],
#   'bug': ['naseem',
#    'demeyer',
#    'akbari',
#    'historical',
#    'denote',
#    'website',
#    'nobody',
#    'dependent',
#    'meanwhile',
#    'baeza'],
#   'bugs': ['tactic',
#    'etemadi',
#    'suri',
#    'nulty',
#    'erick',
#    'revealing',
#    'noteworthy',
#    'sentation',
#    'noisy',
#    'cheah'],
#   'bugzilla': ['naseem',
#    'demeyer',
#    'akbari',
#    'historical',
#    'denote',
#    'website',
#    'nobody',
#    'dependent',
#    'meanwhile',
#    'baeza'],
#   'bui': ['dave',
#    'torrance',
#    'hoi',
#    'rajendran',
#    'expand',
#    'tify',
#    'mcgraw',
#    'writes',
#    'rmn',
#    'humaneval'],
#   'build': ['breazeal',
#    'respect',
#    'attainable',
#    'federated',
#    'enter',
#    'item',
#    'associations',
#    'useful',
#    'department',
#    'having'],
#   'building': ['there',
#    'been',
#    'than',
#    'practical',
#    'found',
#    'june',
#    'oriented',
#    'measure',
#    'similar',
#    'amount'],
#   'builds': ['began',
#    'resour',
#    'nonetheless',
#    'gaps',
#    'harmonic',
#    'gains',
#    'replaced',
#    'member',
#    'attribute',
#    'boost'],
#   'built': ['keywords',
#    'la',
#    'option',
#    'order',
#    'lack',
#    'queries',
#    'database',
#    'instruct',
#    'keyword',
#    'rag'],
#   'burch': ['skgprompt',
#    'gst',
#    'barzilay',
#    'komeili',
#    'alpaca',
#    'vechtomova',
#    'kojima',
#    'gru',
#    'knowledgpt',
#    'velutharambath'],
#   'burden': ['abstracting',
#    'assisted',
#    'assessments',
#    'initialize',
#    'inspection',
#    'visual',
#    'workflow',
#    'portugal',
#    'own',
#    'feng'],
#   'burning': ['regimens',
#    'gavaravarapu',
#    'dependable',
#    'korrapati',
#    'gandhinagar',
#    'advice',
#    'iraq',
#    'gamification',
#    'estimating',
#    'iot'],
#   'bus': ['softmax',
#    'gopali',
#    'carl',
#    'marketing',
#    'carolina',
#    'square',
#    'martí',
#    'categorizing',
#    'master',
#    'specializes'],
#   'bushehrian': ['naseem',
#    'demeyer',
#    'akbari',
#    'historical',
#    'denote',
#    'website',
#    'nobody',
#    'dependent',
#    'meanwhile',
#    'baeza'],
#   'business': ['execution',
#    'cost',
#    'missed',
#    'endpoint',
#    'hypertext',
#    'kaswan',
#    'arcuri',
#    'responsibilities',
#    'karlsson',
#    'uncovered'],
#   'businesses': ['softmax',
#    'gopali',
#    'carl',
#    'marketing',
#    'carolina',
#    'square',
#    'martí',
#    'categorizing',
#    'master',
#    'specializes'],
#   'but': ['it',
#    'also',
#    'requires',
#    'to',
#    'as',
#    'not',
#    'without',
#    'shown',
#    'that',
#    'by'],
#   'button': ['insecure',
#    'pernambuco',
#    'multitude',
#    'win',
#    'ging',
#    'git',
#    'permission',
#    'seamlessly',
#    'perry',
#    'rifkin'],
#   'buy': ['dell',
#    'qualified',
#    'punishments',
#    'universities',
#    'purchase',
#    'purse',
#    'united',
#    'putational',
#    'devoted',
#    'quartey'],
#   'buying': ['dell',
#    'qualified',
#    'punishments',
#    'universities',
#    'purchase',
#    'purse',
#    'united',
#    'putational',
#    'devoted',
#    'quartey'],
#   'by': ['also', 'that', 'their', 'to', 'it', 'be', 'an', 'and', 'in', 'of'],
#   'bytes': ['magazine',
#    'nfv',
#    'firewalls',
#    'adept',
#    'verbal',
#    'finep',
#    'shami',
#    'regimen',
#    'configures',
#    'orchestration'],
#   ...}}

# %%
# Print full vocabularies for inspection
print("\n=== Vocabulary: BoW ===")
print(vocabulary_bow.tolist())

print("\n=== Vocabulary: TF-IDF ===")
print(vocabulary_tfidf.tolist())

print("\n=== Vocabulary: One-Hot ===")
print(vocabulary_onehot)
# Out:
# === Vocabulary: BoW ===
# ['aaai', 'aae', 'aaron', 'abacha', 'abadi', 'abadie', 'abbas', 'abbasian', 'abbeel', 'abbreviation', 'abcde', 'abdel', 'abdelaziz', 'abdi', 'abdin', 'abdul', 'abdullah', 'abe', 'abhimanyu', 'abhishek', 'abidin', 'abilities', 'ability', 'able', 'abnormalities', 'about', 'above', 'abri', 'abrupt', 'absence', 'absent', 'absolute', 'abstr', 'abstract', 'abstracting', 'abstraction', 'abstractions', 'abstracts', 'abuse', 'acad', 'academic', 'academy', 'acc', 'accelerate', 'accelerated', 'accept', 'acceptance', 'accepted', 'access', 'accessed', 'accessibility', 'accessible', 'accompanied', 'accompanying', 'accomplish', 'accordance', 'according', 'account', 'accounting', 'accounts', 'accumulation', 'accuracies', 'accuracy', 'accurate', 'accurately', 'achado', 'acharya', 'achiam', 'achieve', 'achieved', 'achievements', 'achieves', 'achieving', 'acknowledge', 'acknowledgements', 'acknowledgment', 'acl', 'acm', 'acoustic', 'acoustics', 'acquire', 'acquired', 'acquisition', 'acr', 'across', 'acso', 'act', 'acted', 'acteristics', 'acting', 'action', 'actionable', 'actions', 'activation', 'activations', 'active', 'activities', 'activity', 'acts', 'actual', 'actually', 'ad', 'ada', 'adaboost', 'adam', 'adamw', 'adapt', 'adaptability', 'adaptable', 'adaptation', 'adapted', 'adapter', 'adapters', 'adapting', 'adaptive', 'adapts', 'add', 'added', 'adder', 'adding', 'addition', 'additional', 'additionally', 'address', 'addressed', 'addresses', 'addressing', 'adds', 'adept', 'adequately', 'aderemi', 'adhere', 'adhered', 'adherence', 'adheres', 'adhering', 'adi', 'adjust', 'adjustable', 'adjusted', 'adjusting', 'adjustment', 'adjustments', 'adjusts', 'adler', 'administration', 'administrators', 'adopt', 'adopted', 'adopting', 'adoption', 'adopts', 'adriana', 'adriell', 'adults', 'adv', 'advance', 'advanced', 'advancement', 'advancements', 'advances', 'advancing', 'advantage', 'advantages', 'advent', 'adversarial', 'advice', 'affect', 'affected', 'affecting', 'affects', 'affinity', 'affirmation', 'affordances', 'aforementioned', 'aftandilian', 'after', 'ag', 'again', 'against', 'agarwal', 'age', 'agement', 'agencies', 'agent', 'agentic', 'agents', 'ages', 'aggregates', 'aggregating', 'aggregation', 'agram', 'agreement', 'agriculture', 'aguirre', 'agustini', 'ahmad', 'ahmed', 'ahmedin', 'ahn', 'ai', 'aid', 'aida', 'aidan', 'aided', 'aiding', 'aids', 'aila', 'aim', 'aimed', 'aiming', 'aims', 'air', 'airbnb', 'aist', 'ajanthan', 'aji', 'akbar', 'akbari', 'akhtar', 'akinci', 'akkaya', 'akli', 'akmal', 'akyürek', 'al', 'alacapinar', 'alagoas', 'alam', 'alamitos', 'alaniz', 'alarming', 'alawadi', 'albeit', 'albert', 'alberta', 'alberto', 'albuquerque', 'aldoseri', 'alec', 'alejandra', 'aleman', 'alencar', 'alenezi', 'alex', 'alexei', 'alexis', 'alghowinem', 'algorithm', 'algorithmic', 'algorithms', 'alham', 'ali', 'align', 'aligned', 'aligning', 'alignmen', 'alignment', 'aligns', 'alina', 'alkhayyat', 'all', 'allen', 'allender', 'alleviate', 'alleviating', 'allocation', 'allow', 'allowed', 'allowing', 'allows', 'ally', 'almahairi', 'almazrouei', 'almeida', 'almost', 'alone', 'along', 'alongside', 'aloud', 'alowais', 'alpaca', 'alpha', 'already', 'also', 'altenschmidt', 'alter', 'altered', 'altering', 'alternate', 'alternative', 'alternatively', 'alternatives', 'although', 'altman', 'alto', 'altogether', 'aluru', 'alves', 'always', 'am', 'amatriain', 'amazon', 'amazˆonia', 'ambiguities', 'ambiguous', 'amer', 'american', 'amershi', 'amf', 'amir', 'amirhosseini', 'amodei', 'among', 'amongst', 'amount', 'amounting', 'amounts', 'amplify', 'amplifying', 'amundsen', 'an', 'ana', 'anais', 'anal', 'analogous', 'analysed', 'analyses', 'analysis', 'analytical', 'analytics', 'analyze', 'analyzed', 'analyzes', 'analyzing', 'anandkumar', 'anarosa', 'anatom', 'anatomical', 'anatomy', 'anced', 'anchor', 'anchors', 'and', 'andrea', 'andreas', 'andrew', 'andros', 'aneja', 'angelidis', 'angelopoulos', 'anil', 'animal', 'animate', 'animated', 'animation', 'animator', 'anjul ...
#
# === Vocabulary: TF-IDF ===
# ['aaai', 'aae', 'aaron', 'abacha', 'abadi', 'abadie', 'abbas', 'abbasian', 'abbeel', 'abbreviation', 'abcde', 'abdel', 'abdelaziz', 'abdi', 'abdin', 'abdul', 'abdullah', 'abe', 'abhimanyu', 'abhishek', 'abidin', 'abilities', 'ability', 'able', 'abnormalities', 'about', 'above', 'abri', 'abrupt', 'absence', 'absent', 'absolute', 'abstr', 'abstract', 'abstracting', 'abstraction', 'abstractions', 'abstracts', 'abuse', 'acad', 'academic', 'academy', 'acc', 'accelerate', 'accelerated', 'accept', 'acceptance', 'accepted', 'access', 'accessed', 'accessibility', 'accessible', 'accompanied', 'accompanying', 'accomplish', 'accordance', 'according', 'account', 'accounting', 'accounts', 'accumulation', 'accuracies', 'accuracy', 'accurate', 'accurately', 'achado', 'acharya', 'achiam', 'achieve', 'achieved', 'achievements', 'achieves', 'achieving', 'acknowledge', 'acknowledgements', 'acknowledgment', 'acl', 'acm', 'acoustic', 'acoustics', 'acquire', 'acquired', 'acquisition', 'acr', 'across', 'acso', 'act', 'acted', 'acteristics', 'acting', 'action', 'actionable', 'actions', 'activation', 'activations', 'active', 'activities', 'activity', 'acts', 'actual', 'actually', 'ad', 'ada', 'adaboost', 'adam', 'adamw', 'adapt', 'adaptability', 'adaptable', 'adaptation', 'adapted', 'adapter', 'adapters', 'adapting', 'adaptive', 'adapts', 'add', 'added', 'adder', 'adding', 'addition', 'additional', 'additionally', 'address', 'addressed', 'addresses', 'addressing', 'adds', 'adept', 'adequately', 'aderemi', 'adhere', 'adhered', 'adherence', 'adheres', 'adhering', 'adi', 'adjust', 'adjustable', 'adjusted', 'adjusting', 'adjustment', 'adjustments', 'adjusts', 'adler', 'administration', 'administrators', 'adopt', 'adopted', 'adopting', 'adoption', 'adopts', 'adriana', 'adriell', 'adults', 'adv', 'advance', 'advanced', 'advancement', 'advancements', 'advances', 'advancing', 'advantage', 'advantages', 'advent', 'adversarial', 'advice', 'affect', 'affected', 'affecting', 'affects', 'affinity', 'affirmation', 'affordances', 'aforementioned', 'aftandilian', 'after', 'ag', 'again', 'against', 'agarwal', 'age', 'agement', 'agencies', 'agent', 'agentic', 'agents', 'ages', 'aggregates', 'aggregating', 'aggregation', 'agram', 'agreement', 'agriculture', 'aguirre', 'agustini', 'ahmad', 'ahmed', 'ahmedin', 'ahn', 'ai', 'aid', 'aida', 'aidan', 'aided', 'aiding', 'aids', 'aila', 'aim', 'aimed', 'aiming', 'aims', 'air', 'airbnb', 'aist', 'ajanthan', 'aji', 'akbar', 'akbari', 'akhtar', 'akinci', 'akkaya', 'akli', 'akmal', 'akyürek', 'al', 'alacapinar', 'alagoas', 'alam', 'alamitos', 'alaniz', 'alarming', 'alawadi', 'albeit', 'albert', 'alberta', 'alberto', 'albuquerque', 'aldoseri', 'alec', 'alejandra', 'aleman', 'alencar', 'alenezi', 'alex', 'alexei', 'alexis', 'alghowinem', 'algorithm', 'algorithmic', 'algorithms', 'alham', 'ali', 'align', 'aligned', 'aligning', 'alignmen', 'alignment', 'aligns', 'alina', 'alkhayyat', 'all', 'allen', 'allender', 'alleviate', 'alleviating', 'allocation', 'allow', 'allowed', 'allowing', 'allows', 'ally', 'almahairi', 'almazrouei', 'almeida', 'almost', 'alone', 'along', 'alongside', 'aloud', 'alowais', 'alpaca', 'alpha', 'already', 'also', 'altenschmidt', 'alter', 'altered', 'altering', 'alternate', 'alternative', 'alternatively', 'alternatives', 'although', 'altman', 'alto', 'altogether', 'aluru', 'alves', 'always', 'am', 'amatriain', 'amazon', 'amazˆonia', 'ambiguities', 'ambiguous', 'amer', 'american', 'amershi', 'amf', 'amir', 'amirhosseini', 'amodei', 'among', 'amongst', 'amount', 'amounting', 'amounts', 'amplify', 'amplifying', 'amundsen', 'an', 'ana', 'anais', 'anal', 'analogous', 'analysed', 'analyses', 'analysis', 'analytical', 'analytics', 'analyze', 'analyzed', 'analyzes', 'analyzing', 'anandkumar', 'anarosa', 'anatom', 'anatomical', 'anatomy', 'anced', 'anchor', 'anchors', 'and', 'andrea', 'andreas', 'andrew', 'andros', 'aneja', 'angelidis', 'angelopoulos', 'anil', 'animal', 'animate', 'animated', 'animation', 'animator', 'anjul ...
#
# === Vocabulary: One-Hot ===
# ['A', 'AAAI', 'AAE', 'ABCDE', 'ABRI', 'ABSENCE', 'ABSTRACT', 'ACC', 'ACKNOWLEDGMENT', 'ACL', 'ACM', 'ACR', 'ACSO', 'ACTIONS', 'ACTUAL', 'ADA', 'ADDRESSED', 'ADHERENCE', 'AG', 'AI', 'AIST', 'AKBAR', 'AL', 'ALGORITHMIC', 'AM', 'AMF', 'AMOUNT', 'AN', 'ANALYSIS', 'AND', 'ANN', 'ANNOTATED', 'ANSIM', 'ANSWERS', 'ANYTHING', 'APE', 'API', 'APITestGenie', 'APITesting', 'APIs', 'APPENDIX', 'APPLICATION', 'APPROACHES', 'APPROPRIATENESS', 'APQ', 'APR', 'ARCHITECTURE', 'ART', 'AS', 'ASE', 'ASR', 'ASRU', 'ASSESSMENT', 'AT', 'ATTENTION', 'ATTENUATION', 'ATTRIBUTES', 'AUGMENTATION', 'AUGMENTED', 'AUTHORITIES', 'AUXILIARY', 'AVERAGE', 'Aaron', 'Abacha', 'Abadi', 'Abadie', 'Abbas', 'Abbasian', 'Abbeel', 'Abdel', 'Abdelaziz', 'Abdi', 'Abdin', 'Abdul', 'Abdullah', 'Abhimanyu', 'Abhishek', 'Abidin', 'About', 'Abstr', 'Abstract', 'Abstracting', 'Abstracts', 'Abuse', 'Acad', 'Academy', 'Acceptance', 'Accepted', 'Access', 'Accessed', 'According', 'Accounting', 'Accuracy', 'Accurate', 'Achado', 'Acharya', 'Achiam', 'Acknowledgements', 'Acoustics', 'Act', 'Acting', 'Action', 'Actions', 'Activation', 'Active', 'Activity', 'Ada', 'AdaBoost', 'Adam', 'AdamW', 'Adaptability', 'Adaptable', 'Adaptation', 'Adapting', 'Adaptive', 'Adding', 'Additional', 'Additionally', 'Addressing', 'Aderemi', 'Adhere', 'Adherence', 'Adi', 'Adjust', 'Adjusting', 'Adler', 'Adriana', 'Adriell', 'Adv', 'Advanced', 'Advancements', 'Advances', 'Advancing', 'Adversarial', 'Aftandilian', 'After', 'Agarwal', 'Age', 'Agencies', 'Agent', 'Agentic', 'Agents', 'Agriculture', 'Aguirre', 'Agustini', 'Ahmad', 'Ahmed', 'Ahmedin', 'Ahn', 'Ai', 'Aida', 'Aidan', 'Aided', 'Aila', 'Air', 'Ajanthan', 'Aji', 'Akbari', 'Akhtar', 'Akinci', 'Akkaya', 'Akli', 'Akmal', 'Akyürek', 'Al', 'Alacapinar', 'Alagoas', 'Alam', 'Alamitos', 'Alaniz', 'Alawadi', 'Albert', 'Alberta', 'Alberto', 'Albuquerque', 'Aldoseri', 'Alec', 'Alejandra', 'Aleman', 'Alencar', 'Alenezi', 'Alex', 'Alexei', 'Alexis', 'Alghowinem', 'Algorithm', 'Alham', 'Ali', 'Align', 'Alignment', 'Alina', 'Alkhayyat', 'All', 'Allen', 'Allender', 'Almahairi', 'Almazrouei', 'Almeida', 'Alowais', 'Alpaca', 'Also', 'Altenschmidt', 'Alternatively', 'Although', 'Altman', 'Alto', 'Altogether', 'Aluru', 'Alves', 'Am', 'Amatriain', 'Amazon', 'Amazˆonia', 'Amer', 'American', 'Amershi', 'Amir', 'Amirhosseini', 'Amodei', 'Among', 'Amundsen', 'An', 'Ana', 'Anais', 'Anal', 'Analysis', 'Analytics', 'Analyzing', 'Anandkumar', 'Anarosa', 'Anatomical', 'Anatomy', 'And', 'Andrea', 'Andreas', 'Andrew', 'Andros', 'Aneja', 'Angelidis', 'Angelopoulos', 'Anil', 'Animal', 'Anjuli', 'Anmol', 'Anna', 'AnnoLLM', 'Annotation', 'Annu', 'Annual', 'Anoop', 'Another', 'Answer', 'Answering', 'Answers', 'Anvik', 'Anwar', 'Any', 'Anything', 'Apart', 'Apitestgenie', 'Apoorv', 'Appendix', 'Appl', 'Applicability', 'Application', 'Applications', 'Applied', 'Apply', 'Applying', 'Approach', 'Approaches', 'Approximate', 'April', 'ArXiv', 'Araji', 'Aralikatte', 'Aramis', 'Araujo', 'Archana', 'Architectural', 'Architecture', 'Archive', 'Arcuri', 'Ardila', 'Are', 'Arefi', 'Arena', 'Aridas', 'Arifianto', 'Armand', 'Armin', 'Arnold', 'Arrange', 'Arrangement', 'Art', 'Artes', 'Artetxe', 'Article', 'Articles', 'Artif', 'Artificial', 'Arts', 'Artzi', 'Arulkumaran', 'Arun', 'Arya', 'As', 'Asadpour', 'Ashish', 'Ashraf', 'Asia', 'Asian', 'Aside', 'Asim', 'Askell', 'Asleep', 'Asopa', 'Assess', 'Assessing', 'Assessment', 'Assigned', 'Assistant', 'Assistive', 'Assoc', 'Associates', 'Association', 'Associations', 'Assumption', 'Assured', 'Astouati', 'Asymmetry', 'At', 'Athena', 'AthenaLLM', 'Athithan', 'Attariyan', 'Attention', 'Attenuation', 'Attribute', 'Attribution', 'Au', 'Augmentation', 'Augmented', 'Augmenting', 'August', 'Augustin', 'Auli', 'Auri', 'Aussem', 'Author', 'Authorea', 'Authorities', 'Authorization', 'Authorized', 'Authors', 'Auto', 'AutoChip', 'AutoEncoder', 'Autochip', 'Autoencoders', 'Automated', 'Automatic', 'Automatically', 'Automating', 'Automation', 'Autonomous', 'Autonomously', 'A ...
